# %%
import numpy as np
import random
from math import *

# %%
NUMBER_OF_NODE = 10;
NUMBER_OF_VOTE = "vote"
POINT = "point"
NUMBER_OF_VALIDATOR = "validator"
NUMBER_OF_DEPOSIT = "deposit"
NODE = "node"
SPEED = "speed"
RANKING = "ranking"
NUMBER_OF_EPOCH = "epoch"

#init nodes
def init_nodes(number_of_node):
    nodes = []
    for i in range(number_of_node):
        nodes.append({})
        nodes[i][NODE] = i+1
        nodes[i][SPEED] = 0
        nodes[i][RANKING] = 0
        nodes[i][NUMBER_OF_DEPOSIT] = 0
        nodes[i][NUMBER_OF_VOTE] = 0
        nodes[i][NUMBER_OF_VALIDATOR] = 0
        nodes[i][NUMBER_OF_EPOCH] = 0
        nodes[i][POINT] = 0
    
    return nodes

# %%
#random speed of nodes
def random_nodes_speed(nodes):
    arr_speed = np.random.randint(low=5,high=10,size=len(nodes)).tolist()
    for i in range(len(arr_speed)):
        nodes[i][SPEED] = arr_speed[i]
    return arr_speed

# %%
#random number of epochs that masternode join in blockchain
def random_epochs_of_nodes(nodes):
    arr_epochs = np.random.randint(low=1,high=9000,size=len(nodes)).tolist()
    for i in range(len(arr_speed)):
        nodes[i][NUMBER_OF_EPOCH] = arr_speed[i]
    return arr_epochs

# %%
def deposit_votes(nodes):
    arr_deposit_vote = np.random.randint(low=50000,high=500000,size=len(nodes)).tolist()
#     arr_deposit_vote = np.sort(arr_deposit_vote)[::-1]
    for i in range(len(arr_deposit_vote)):
        nodes[i][NUMBER_OF_DEPOSIT] = arr_deposit_vote[i]
    return arr_deposit_vote

# %%
# chose a leader node by voting
def vote_leader(nodes):
    
    #random array with length is number of canidate of leader
    arr_random = np.random.rand(len(nodes)).tolist()
    
    #select lead node
    index_of_leader = -1
    maximum = -1
    arr_leader = []
    for i in range(len(nodes)):
        multi = nodes[i][NUMBER_OF_DEPOSIT] * arr_random[i]
        arr_leader.append(multi)
        if multi > maximum:
            index_of_leader = i
            maximum = arr_leader[i]
    nodes[index_of_leader][NUMBER_OF_VOTE] += 1
    return index_of_leader

# %%
# Ranking for each masternode
def ranking(nodes, arr_deposit_vote, arr_speed):
    total_deposit = sum(arr_deposit_vote)

    total_vote = 2000  # Total voting in one epoch
    total_epoch = 9000  # Total epoch in blockchain
    speed_arg = sum(arr_speed)/len(nodes)
    a = 0.6
    b = 0.2
    for i in range(len(arr_deposit_vote)):
        trust = b*nodes[i][NUMBER_OF_EPOCH]/total_epoch + b*(
                nodes[i][SPEED]/speed_arg) + b*(
                nodes[i][NUMBER_OF_VOTE]/total_vote) + b*(
                nodes[i][NUMBER_OF_VOTE]/nodes[i][NUMBER_OF_EPOCH]) + b*(
                nodes[i][NUMBER_OF_VALIDATOR]/nodes[i][NUMBER_OF_EPOCH])
        
        vote_arg_deposit = arr_deposit_vote[i]/total_deposit
        
        nodes[i][RANKING] = a*(vote_arg_deposit) + (1-a)*trust

# %%
# Random validator base on Ranking of each node
def random_validator(nodes, arr_deposit_vote, leader):
    point_arr = []
    index_of_validator = -1
    maximum = -1
    
    total = sum(arr_deposit_vote) - arr_deposit_vote[leader]
    mean = total/(len(nodes) - 1)
    
    arr_random = np.random.rand(len(nodes)-1).tolist()
    for i in range(len(arr_random)):
        nodes[i][POINT] = nodes[i][RANKING] * arr_random[i] * 1/mean
        if nodes[i][POINT] > maximum:
            maximum = nodes[i][POINT]
            if i != leader:
                index_of_validator = i
    nodes[index_of_validator][NUMBER_OF_VALIDATOR] += 1
    return index_of_validator

# %%
nodes = init_nodes(150)
arr_deposit_vote = deposit_votes(nodes)
arr_speed = random_nodes_speed(nodes)
arr_epochs = random_epochs_of_nodes(nodes)
random_ranking(nodes, arr_deposit_vote, arr_speed)
for i in range(2000):
    leader = random_lead(nodes)
    validator = random_validator(nodes, arr_deposit_vote, leader)
nodes
# Out:
# [{'deposit': 0,
#   'epoch': 9,
#   'node': 1,
#   'point': 2.65825458807291e-07,
#   'ranking': 0.11116727850398808,
#   'speed': 9,
#   'validator': 0,
#   'vote': 2000},
#  {'deposit': 0,
#   'epoch': 8,
#   'node': 2,
#   'point': 3.563676189818925e-07,
#   'ranking': 0.09958856433220246,
#   'speed': 8,
#   'validator': 5,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 7,
#   'node': 3,
#   'point': 8.109694796849379e-08,
#   'ranking': 0.08797251865348277,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 4,
#   'point': 5.90287589375636e-08,
#   'ranking': 0.06487570635455626,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 8,
#   'node': 5,
#   'point': 4.445448192631234e-08,
#   'ranking': 0.09950725906670778,
#   'speed': 8,
#   'validator': 5,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 8,
#   'node': 6,
#   'point': 4.1686210649605106e-08,
#   'ranking': 0.09949611533329462,
#   'speed': 8,
#   'validator': 3,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 7,
#   'point': 5.074071265350626e-08,
#   'ranking': 0.07637456687875234,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 8,
#   'point': 2.329556377251916e-07,
#   'ranking': 0.07631720597728882,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 9,
#   'point': 2.0758366139579587e-07,
#   'ranking': 0.06476268543725545,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 10,
#   'point': 1.4597429320608636e-07,
#   'ranking': 0.0647580373273976,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 11,
#   'point': 7.259757222897787e-08,
#   'ranking': 0.11094342142764771,
#   'speed': 9,
#   'validator': 123,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 12,
#   'point': 1.7187568461143967e-07,
#   'ranking': 0.06470514858210646,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 13,
#   'point': 9.949208173186887e-08,
#   'ranking': 0.11083701343635918,
#   'speed': 9,
#   'validator': 119,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 14,
#   'point': 1.7401284067781624e-07,
#   'ranking': 0.07619340789675291,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 7,
#   'node': 15,
#   'point': 2.2037261723474393e-07,
#   'ranking': 0.08767933582506687,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 16,
#   'point': 2.3632154974751335e-07,
#   'ranking': 0.07612868626611385,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 8,
#   'node': 17,
#   'point': 1.669041824336318e-07,
#   'ranking': 0.09920082106065306,
#   'speed': 8,
#   'validator': 4,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 18,
#   'point': 2.3703173122352067e-07,
#   'ranking': 0.07609613483430175,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 19,
#   'point': 6.115894035468293e-08,
#   'ranking': 0.06448479591666839,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 7,
#   'node': 20,
#   'point': 2.0747471591488637e-07,
#   'ranking': 0.08754521512831667,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 21,
#   'point': 3.9171586365811473e-07,
#   'ranking': 0.1106321740208568,
#   'speed': 9,
#   'validator': 117,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 7,
#   'node': 22,
#   'point': 2.863114038785971e-07,
#   'ranking': 0.08749980441465804,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node':

#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 56,
#   'point': 6.818110035063262e-08,
#   'ranking': 0.10878835535080712,
#   'speed': 9,
#   'validator': 92,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 8,
#   'node': 57,
#   'point': 1.2077212189788992e-07,
#   'ranking': 0.09720220713581036,
#   'speed': 8,
#   'validator': 1,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 7,
#   'node': 58,
#   'point': 1.2916533416084192e-07,
#   'ranking': 0.08554947511366999,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 59,
#   'point': 2.692770799497899e-08,
#   'ranking': 0.07393269629459416,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 8,
#   'node': 60,
#   'point': 8.032920802379201e-09,
#   'ranking': 0.09697050545765942,
#   'speed': 8,
#   'validator': 3,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 8,
#   'node': 61,
#   'point': 3.112933586441872e-08,
#   'ranking': 0.09692889241104555,
#   'speed': 8,
#   'validator': 3,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 62,
#   'point': 2.1179730792358548e-07,
#   'ranking': 0.062126884566094095,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 63,
#   'point': 3.8863672056201805e-08,
#   'ranking': 0.062115579541802586,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 64,
#   'point': 2.080187415900302e-07,
#   'ranking': 0.06208296945876198,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 65,
#   'point': 2.2990666957662852e-07,
#   'ranking': 0.10822813347907487,
#   'speed': 9,
#   'validator': 86,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 66,
#   'point': 2.1602841505556417e-07,
#   'ranking': 0.0735860235457951,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 67,
#   'point': 9.769505118256501e-08,
#   'ranking': 0.07349581795637701,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 7,
#   'node': 68,
#   'point': 1.4921822314880473e-07,
#   'ranking': 0.08502983989205302,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 69,
#   'point': 1.707764267515916e-07,
#   'ranking': 0.10808926203281695,
#   'speed': 9,
#   'validator': 64,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 70,
#   'point': 9.031696388236698e-08,
#   'ranking': 0.07343939547456935,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 7,
#   'node': 71,
#   'point': 1.996236974641435e-07,
#   'ranking': 0.08494774283497372,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 72,
#   'point': 2.809271575193199e-07,
#   'ranking': 0.10786937857720681,
#   'speed': 9,
#   'validator': 82,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 73,
#   'point': 1.2223477109643933e-07,
#   'ranking': 0.06167686835269512,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 74,
#   'point': 4.222566071570083e-08,
#   'ranking': 0.061564991134349864,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 75,
#   'point': 1.1997154455334314e-07,
#   'ranking': 0.061538979314514415,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 76,
#   'point': 2.3795487546095635e-07,
#   'ranking': 0.07306436485679522,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 77,
#   'point': 2.3218011808316623e-07,
#   'ranking': 0.1076877797109937,
#   'speed': 9,
#   'validator': 64,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 78,
#   'point': 2.881097383971557e-07,
#   'ranking': 0.10768430462570565,
#   'speed': 9,
#   'validator': 70,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 8,
#   'node': 79,
#   'point': 2.6343624494121016e-07,
#   'ranking': 0.09611460808030042,
#   'speed': 8,
#   'validator': 1,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 7,
#   'node': 80,
#   'point': 2.413192473862886e-07,
#   'ranking': 0.08455192035669978,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 8,
#   'node': 81,
#   'point': 2.7410879515700325e-07,
#   'ranking': 0.0960602383914899,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 8,
#   'node': 82,
#   'point': 8.556696061905281e-08,
#   'ranking': 0.09600815610059052,
#   'speed': 8,
#   'validator': 2,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 83,
#   'point': 1.0358083733507682e-07,
#   'ranking': 0.1075289081958206,
#   'speed': 9,
#   'validator': 61,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 84,
#   'point': 4.145237199426846e-08,
#   'ranking': 0.06132755629861399,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 7,
#   'node': 85,
#   'point': 6.921691763208888e-08,
#   'ranking': 0.08440504301775295,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 7,
#   'node': 86,
#   'point': 1.8283031750644962e-07,
#   'ranking': 0.0843972863927851,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node':

#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 150,
#   'point': 0,
#   'ranking': 0.07006108471352787,
#   'speed': 6,
#   'validator': 124,
#   'vote': 0}]

# %%
from mpl_toolkits.axisartist.parasite_axes import HostAxes, ParasiteAxes
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(12, 9))

host = HostAxes(fig, [0.15, 0.1, 0.65, 0.8])
par1 = ParasiteAxes(host, sharex=host)
par2 = ParasiteAxes(host, sharex=host)
host.parasites.append(par1)
host.parasites.append(par2)

host.set_xlabel("Node index")
host.set_ylabel("Leader")

host.axis["right"].set_visible(False)
par1.axis["right"].set_visible(True)
par1.set_ylabel("Deposit")

par1.axis["right"].major_ticklabels.set_visible(True)
par1.axis["right"].label.set_visible(True)

par2.set_ylabel("Validator")
offset = (60, 0)
new_axisline = par2.get_grid_helper().new_fixed_axis
par2.axis["right2"] = new_axisline(loc="right", axes=par2, offset=offset)

fig.add_axes(host)

x_array = []
leader_y_array = []
deposit_y_array = []
validator_y_array = []
for i in range(len(nodes)):
    x_array.append(i)
    leader_y_array.append(nodes[i][NUMBER_OF_VOTE])
    deposit_y_array.append(nodes[i][NUMBER_OF_DEPOSIT])
    validator_y_array.append(nodes[i][NUMBER_OF_VALIDATOR])

host.set_xlabel("Node index")
host.set_ylabel("Leader")
par1.set_ylabel("Deposit")

p1, = host.plot(x_array, leader_y_array, label="Leader")
p2, = par1.plot(x_array, deposit_y_array, label="Deposit")
p3, = par2.plot(x_array, validator_y_array, label="Validator")

# par1.set_ylim(0, 4)
# par2.set_ylim(1, 65)

host.legend()

host.axis["left"].label.set_color(p1.get_color())
par1.axis["right"].label.set_color(p2.get_color())
par2.axis["right2"].label.set_color(p3.get_color())

plt.show()

# %%
nodes = init_nodes(150)
arr_deposit_vote = deposit_votes(nodes)
arr_speed = random_nodes_speed(nodes)
arr_epochs = random_epochs_of_nodes(nodes)
random_ranking(nodes, arr_deposit_vote, arr_speed)
leader = random_lead(nodes)
for i in range(2000):
#     leader = random_lead(nodes)
    validator = random_validator(nodes, arr_deposit_vote, leader)
nodes
# Out:
# [{'deposit': 0,
#   'epoch': 5,
#   'node': 1,
#   'point': 2.94151415830099e-08,
#   'ranking': 0.06585016623088151,
#   'speed': 5,
#   'validator': 0,
#   'vote': 1},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 2,
#   'point': 8.759992250679193e-08,
#   'ranking': 0.07738928027964762,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 3,
#   'point': 2.6472253879365627e-07,
#   'ranking': 0.06581812786942903,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 4,
#   'point': 3.444140723173314e-07,
#   'ranking': 0.11207028265015193,
#   'speed': 9,
#   'validator': 113,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 8,
#   'node': 5,
#   'point': 2.5119971819236987e-07,
#   'ranking': 0.10048831729294316,
#   'speed': 8,
#   'validator': 3,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 6,
#   'point': 6.349159875303852e-08,
#   'ranking': 0.06576984605872017,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 7,
#   'point': 6.488524830736181e-08,
#   'ranking': 0.07729063416473546,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 8,
#   'point': 4.440376160726192e-08,
#   'ranking': 0.06571531676752806,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 8,
#   'node': 9,
#   'point': 3.1474886010473115e-07,
#   'ranking': 0.10019471774859273,
#   'speed': 8,
#   'validator': 4,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 8,
#   'node': 10,
#   'point': 4.330484663287271e-08,
#   'ranking': 0.10017575103861287,
#   'speed': 8,
#   'validator': 4,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 11,
#   'point': 2.0208838945402558e-07,
#   'ranking': 0.06544009122347064,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 12,
#   'point': 2.1964790143897964e-07,
#   'ranking': 0.0654285253749863,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 13,
#   'point': 1.0223425779666578e-07,
#   'ranking': 0.07694873679049544,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 14,
#   'point': 2.867219596501446e-07,
#   'ranking': 0.1116024104386808,
#   'speed': 9,
#   'validator': 105,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 8,
#   'node': 15,
#   'point': 3.4390575356296527e-07,
#   'ranking': 0.10002914349660638,
#   'speed': 8,
#   'validator': 4,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 16,
#   'point': 9.843375222441502e-08,
#   'ranking': 0.1114500680299743,
#   'speed': 9,
#   'validator': 114,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 17,
#   'point': 4.448367357479159e-08,
#   'ranking': 0.11140963561782129,
#   'speed': 9,
#   'validator': 97,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 18,
#   'point': 2.7640551513998917e-08,
#   'ranking': 0.07663725984045454,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 19,
#   'point': 2.1558726654978242e-08,
#   'ranking': 0.06468906397348259,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 20,
#   'point': 1.507815623459418e-07,
#   'ranking': 0.06441483161863018,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 7,
#   'node': 21,
#   'point': 3.22956278862078e-07,
#   'ranking': 0.0874807409661839,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 22,
#   'point': 2.857549239853577e-07,
#   'ranking': 0.11053192868665018,
#   'speed': 9,
#   'validator': 83,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 23,
#   'point': 5.4571237273016386e-08,
#   'ranking': 0.06424195262023266,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 24,
#   'point': 2.3514138842405718e-07,
#   'ranking': 0.07563444310781153,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 25,
#   'point': 3.381417587236734e-07,
#   'ranking': 0.11032997487523455,
#   'speed': 9,
#   'validator': 97,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 26,
#   'point': 3.22844988959194e-07,
#   'ranking': 0.11031778427870188,
#   'speed': 9,
#   'validator': 87,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 27,
#   'point': 2.777379688321736e-07,
#   'ranking': 0.07560647361826353,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 28,
#   'point': 1.981452313193894e-07,
#   'ranking': 0.06403267804322514,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 7,
#   'node': 29,
#   'point': 1.7910403045548423e-07,
#   'ranking': 0.0871611422915148,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 30,
#   'point': 7.75257502675239e-08,
#   'ranking': 0.0754912957088419,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 31,
#   'point': 1.0493761387402847e-07,
#   'ranking': 0.11014381597601497,
#   'speed': 9,
#   'validator': 83,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 7,
#   'node': 32,
#   'point': 2.3788119970574954e-07,
#   'ranking': 0.08689922868664086,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 33,
#   'point': 2.296000639550615e-07,
#   'ranking': 0.0753024295680796,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 34,
#   'point': 4.194975082574325e-07,
#   'ranking': 0.11000733255622745,
#   'speed': 9,
#   'validator': 96,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 35,
#   'point': 1.3919000353588678e-07,
#   'ranking': 0.06369002776749098,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 36,
#   'point': 2.7611875125219287e-07,
#   'ranking': 0.07519103218530937,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 7,
#   'node': 37,
#   'point': 7.546733787803848e-09,
#   'ranking': 0.08669520840091154,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 38,
#   'point': 2.514296049822672e-07,
#   'ranking': 0.07508458472938355,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 39,
#   'point': 5.352285255798779e-08,
#   'ranking': 0.1096896561832455,
#   'speed': 9,
#   'validator': 77,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 40,
#   'point': 2.9318660728370864e-08,
#   'ranking': 0.10956065372085713,
#   'speed': 9,
#   'validator': 82,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 41,
#   'point': 1.4873083731075667e-07,
#   'ranking': 0.10955107425078285,
#   'speed': 9,
#   'validator': 77,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 42,
#   'point': 9.892664144824149e-08,
#   'ranking': 0.06323719756672179,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 43,
#   'point': 2.2884552599340814e-07,
#   'ranking': 0.06319601225307464,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 44,
#   'point': 1.802028670638777e-07,
#   'ranking': 0.0745982584217158,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 45,
#   'point': 3.5361006355525586e-08,
#   'ranking': 0.07454526697187341,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 8,
#   'node': 46,
#   'point': 1.0295917219885932e-07,
#   'ranking': 0.09763368326834747,
#   'speed': 8,
#   'validator': 1,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 47,
#   'point': 2.704827016242738e-07,
#   'ranking': 0.074475951976871,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 7,
#   'node': 48,
#   'point': 1.561462597273454e-07,
#   'ranking': 0.08601671600125188,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 8,
#   'node': 49,
#   'point': 3.57648675972663e-07,
#   'ranking': 0.09756499302139338,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 7,
#   'node': 50,
#   'point': 2.032105447408006e-08,
#   'ranking': 0.08596375658977096,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 8,
#   'node': 51,
#   'point': 1.4451951695172904e-07,
#   'ranking': 0.09750708368306804,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 52,
#   'point': 1.8285260575592442e-07,
#   'ranking': 0.07432332122291144,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 53,
#   'point': 2.2139158226650454e-07,
#   'ranking': 0.07426981715928581,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 54,
#   'point': 1.251797364966619e-07,
#   'ranking': 0.10894596571803007,
#   'speed': 9,
#   'validator': 69,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 55,
#   'point': 1.4626041255715212e-07,
#   'ranking': 0.0742168737669856,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 56,
#   'point': 7.516870388137932e-08,
#   'ranking': 0.10890920169826336,
#   'speed': 9,
#   'validator': 58,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 7,
#   'node': 57,
#   'point': 1.1793080522776206e-07,
#   'ranking': 0.08575118206153383,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 58,
#   'point': 1.29192687825107e-07,
#   'ranking': 0.0740319163063205,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 8,
#   'node': 59,
#   'point': 1.709031889697374e-08,
#   'ranking': 0.09715847427210372,
#   'speed': 8,
#   'validator': 2,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 60,
#   'point': 4.3123270253462885e-08,
#   'ranking': 0.07394406711921783,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 61,
#   'point': 2.1009419399823705e-07,
#   'ranking': 0.0738319969308571,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 62,
#   'point': 2.3214146660380193e-08,
#   'ranking': 0.10853353589105244,
#   'speed': 9,
#   'validator': 59,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 63,
#   'point': 1.0147631503775761e-07,
#   'ranking': 0.10852730442974994,
#   'speed': 9,
#   'validator': 52,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 8,
#   'node': 64,
#   'point': 1.655768320005227e-07,
#   'ranking': 0.09695298022174759,
#   'speed': 8,
#   'validator': 1,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 65,
#   'point': 8.773359958358953e-08,
#   'ranking': 0.062222927119859536,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 66,
#   'point': 2.4374179306673204e-07,
#   'ranking': 0.07377261382790495,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 67,
#   'point': 1.2995122922507725e-10,
#   'ranking': 0.10838401285815377,
#   'speed': 9,
#   'validator': 48,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 68,
#   'point': 1.880782615813698e-07,
#   'ranking': 0.07366587802672606,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 69,
#   'point': 1.871868134478696e-07,
#   'ranking': 0.06205092917640195,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 70,
#   'point': 2.3380571611285742e-07,
#   'ranking': 0.07361988695886103,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 8,
#   'node': 71,
#   'point': 2.7624234972097654e-07,
#   'ranking': 0.09672755831056802,
#   'speed': 8,
#   'validator': 1,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 7,
#   'node': 72,
#   'point': 1.3745753853969078e-07,
#   'ranking': 0.08515595736328913,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 73,
#   'point': 1.4402761028863647e-07,
#   'ranking': 0.06200581916347688,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 74,
#   'point': 5.0082185949219896e-08,
#   'ranking': 0.07356252227268038,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 75,
#   'point': 1.0223795445035535e-07,
#   'ranking': 0.06198155010467664,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 8,
#   'node': 76,
#   'point': 1.516453708284547e-07,
#   'ranking': 0.09660321742977099,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 77,
#   'point': 2.66474669236623e-07,
#   'ranking': 0.07330413288756622,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 78,
#   'point': 1.507604558768287e-07,
#   'ranking': 0.0616530768038852,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 79,
#   'point': 2.7580538020984956e-07,
#   'ranking': 0.10791216788986253,
#   'speed': 9,
#   'validator': 47,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 80,
#   'point': 9.381570686752141e-08,
#   'ranking': 0.06153397419518565,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 8,
#   'node': 81,
#   'point': 2.5777900761899264e-07,
#   'ranking': 0.09623991843008071,
#   'speed': 8,
#   'validator': 1,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 82,
#   'point': 1.7188519136221838e-07,
#   'ranking': 0.07305481035874312,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 83,
#   'point': 2.0550640171557826e-07,
#   'ranking': 0.07300540720538341,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 84,
#   'point': 7.32222124441624e-08,
#   'ranking': 0.061434543140417915,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 8,
#   'node': 85,
#   'point': 2.3141981057947312e-07,
#   'ranking': 0.09609992680971416,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 86,
#   'point': 3.0799827182278364e-07,
#   'ranking': 0.10766813169067908,
#   'speed': 9,
#   'validator': 53,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 87,
#   'point': 1.34010523181724e-07,
#   'ranking': 0.07291433816295477,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 88,
#   'point': 3.882533927193632e-07,
#   'ranking': 0.10759458763196494,
#   'speed': 9,
#   'validator': 45,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 89,
#   'point': 1.755612521682173e-07,
#   'ranking': 0.06128119152332567,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 90,
#   'point': 3.4973878651891186e-07,
#   'ranking': 0.10750771561488658,
#   'speed': 9,
#   'validator': 50,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 7,
#   'node': 91,
#   'point': 2.903297991253769e-07,
#   'ranking': 0.08417755386207292,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 92,
#   'point': 3.05589983120931e-08,
#   'ranking': 0.07254490381704634,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 8,
#   'node': 93,
#   'point': 1.5836607312224904e-07,
#   'ranking': 0.0956659191462983,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 94,
#   'point': 2.2861681792257356e-08,
#   'ranking': 0.10723207357213026,
#   'speed': 9,
#   'validator': 42,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 95,
#   'point': 2.321834926726773e-08,
#   'ranking': 0.06074543002393676,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 8,
#   'node': 96,
#   'point': 3.394400307341741e-07,
#   'ranking': 0.09533461045051832,
#   'speed': 8,
#   'validator': 1,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 97,
#   'point': 2.8054175648966595e-07,
#   'ranking': 0.07218258198738038,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 98,
#   'point': 2.1978650612701483e-07,
#   'ranking': 0.07213285845040615,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 7,
#   'node': 99,
#   'point': 4.388791819095918e-08,
#   'ranking': 0.0836613838207122,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 8,
#   'node': 100,
#   'point': 3.439841378447222e-07,
#   'ranking': 0.09518800290851182,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 101,
#   'point': 7.270345073938326e-08,
#   'ranking': 0.07203890595544678,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 7,
#   'node': 102,
#   'point': 6.54383324553672e-08,
#   'ranking': 0.08353321435572159,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 103,
#   'point': 9.827138306464028e-08,
#   'ranking': 0.0603666885340264,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 104,
#   'point': 3.1755725026288394e-08,
#   'ranking': 0.10662939995484787,
#   'speed': 9,
#   'validator': 32,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 105,
#   'point': 1.1383502871027972e-07,
#   'ranking': 0.07190368805093664,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 106,
#   'point': 1.762291365977859e-07,
#   'ranking': 0.060318070320522284,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 8,
#   'node': 107,
#   'point': 1.971100978264351e-09,
#   'ranking': 0.09501768697903049,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 108,
#   'point': 1.3679972115012238e-07,
#   'ranking': 0.07181176999192951,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 109,
#   'point': 3.6965721293241253e-07,
#   'ranking': 0.10649953245670028,
#   'speed': 9,
#   'validator': 34,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 110,
#   'point': 2.54199744473369e-07,
#   'ranking': 0.10647244402209223,
#   'speed': 9,
#   'validator': 37,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 7,
#   'node': 111,
#   'point': 2.2832889726188687e-08,
#   'ranking': 0.08325106852559043,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 8,
#   'node': 112,
#   'point': 1.289931987593133e-07,
#   'ranking': 0.09480852453628805,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 8,
#   'node': 113,
#   'point': 1.401020034699304e-07,
#   'ranking': 0.09477888905194451,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 114,
#   'point': 2.6017095322366484e-08,
#   'ranking': 0.05998485534223588,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 8,
#   'node': 115,
#   'point': 3.179840703815404e-07,
#   'ranking': 0.0946366066887341,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 116,
#   'point': 2.5665312534516414e-08,
#   'ranking': 0.07134232790074721,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 117,
#   'point': 1.901026125107584e-07,
#   'ranking': 0.07120337752712785,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 118,
#   'point': 4.1472303712468075e-08,
#   'ranking': 0.10590701499999833,
#   'speed': 9,
#   'validator': 24,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 119,
#   'point': 3.803574717112528e-07,
#   'ranking': 0.10590030296327405,
#   'speed': 9,
#   'validator': 33,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 8,
#   'node': 120,
#   'point': 1.399447054796131e-07,
#   'ranking': 0.094329647147658,
#   'speed': 8,
#   'validator': 1,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 7,
#   'node': 121,
#   'point': 1.694930053517842e-07,
#   'ranking': 0.08266877130619181,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 122,
#   'point': 1.2023656014127584e-07,
#   'ranking': 0.05951810447341559,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 123,
#   'point': 1.306964502202841e-07,
#   'ranking': 0.1056730068079495,
#   'speed': 9,
#   'validator': 21,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 124,
#   'point': 2.3723837244256283e-08,
#   'ranking': 0.07095692243165473,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 125,
#   'point': 1.271005817603098e-07,
#   'ranking': 0.05936310288070855,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 7,
#   'node': 126,
#   'point': 1.7972277954880127e-07,
#   'ranking': 0.08249582823107138,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 127,
#   'point': 1.8101341986754832e-07,
#   'ranking': 0.059342165811499356,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 128,
#   'point': 1.0664693190044322e-07,
#   'ranking': 0.10557040395539796,
#   'speed': 9,
#   'validator': 25,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 129,
#   'point': 1.5150549727763065e-08,
#   'ranking': 0.0592882132108134,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 8,
#   'node': 130,
#   'point': 3.785347705625392e-07,
#   'ranking': 0.09395127409890434,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 131,
#   'point': 1.5184580349603962e-07,
#   'ranking': 0.0591830633085264,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 7,
#   'node': 132,
#   'point': 3.034133406799648e-07,
#   'ranking': 0.08230311748693478,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 133,
#   'point': 1.5144025252168306e-07,
#   'ranking': 0.10541706835748646,
#   'speed': 9,
#   'validator': 24,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 134,
#   'point': 3.8857223566756053e-07,
#   'ranking': 0.10539087699699906,
#   'speed': 9,
#   'validator': 23,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 135,
#   'point': 3.349050426021493e-07,
#   'ranking': 0.10537054865665747,
#   'speed': 9,
#   'validator': 18,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 136,
#   'point': 3.745085386026446e-07,
#   'ranking': 0.10527483405181821,
#   'speed': 9,
#   'validator': 21,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 8,
#   'node': 137,
#   'point': 1.4456007140155979e-08,
#   'ranking': 0.09368577219754773,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 7,
#   'node': 138,
#   'point': 6.877073882243886e-10,
#   'ranking': 0.08211325815696745,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 139,
#   'point': 1.1094116683019852e-07,
#   'ranking': 0.0589663558316619,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 140,
#   'point': 1.3414477461087515e-07,
#   'ranking': 0.05893085732717256,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 141,
#   'point': 1.8391256466882393e-07,
#   'ranking': 0.07049622681314896,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 142,
#   'point': 1.707438679372366e-07,
#   'ranking': 0.05891616773844661,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 8,
#   'node': 143,
#   'point': 1.5404417980641201e-07,
#   'ranking': 0.09354773491722977,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 8,
#   'node': 144,
#   'point': 2.078641613649511e-07,
#   'ranking': 0.09352968130055131,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 8,
#   'node': 145,
#   'point': 3.7089675617705435e-07,
#   'ranking': 0.09348670183866283,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 6,
#   'node': 146,
#   'point': 8.755759469707485e-09,
#   'ranking': 0.07031548239701486,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 147,
#   'point': 1.7967595341547508e-07,
#   'ranking': 0.058741895071325906,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 148,
#   'point': 1.3583684342496033e-07,
#   'ranking': 0.10499036544048175,
#   'speed': 9,
#   'validator': 25,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 9,
#   'node': 149,
#   'point': 2.567420769680384e-07,
#   'ranking': 0.10493541965059076,
#   'speed': 9,
#   'validator': 26,
#   'vote': 0},
#  {'deposit': 0,
#   'epoch': 5,
#   'node': 150,
#   'point': 0,
#   'ranking': 0.058656096339356194,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0}]

# %%
from mpl_toolkits.axisartist.parasite_axes import HostAxes, ParasiteAxes
import matplotlib.pyplot as plt

# fig, ax = plt.subplots(figsize=(12, 9))
fig = plt.figure(figsize=(12, 9))

host = HostAxes(fig, [0.15, 0.1, 0.65, 0.8])
par1 = ParasiteAxes(host, sharex=host)
par2 = ParasiteAxes(host, sharex=host)
host.parasites.append(par1)
host.parasites.append(par2)

host.set_xlabel("Node index")
host.set_ylabel("Leader")

host.axis["right"].set_visible(False)
par1.axis["right"].set_visible(True)
par1.set_ylabel("Deposit")

par1.axis["right"].major_ticklabels.set_visible(True)
par1.axis["right"].label.set_visible(True)

par2.set_ylabel("Validator")
offset = (60, 0)
new_axisline = par2.get_grid_helper().new_fixed_axis
par2.axis["right2"] = new_axisline(loc="right", axes=par2, offset=offset)

fig.add_axes(host)

x_array = []
leader_y_array = []
deposit_y_array = []
validator_y_array = []
for i in range(len(nodes)):
    x_array.append(i)
    leader_y_array.append(nodes[i][NUMBER_OF_VOTE])
    deposit_y_array.append(nodes[i][NUMBER_OF_DEPOSIT])
    validator_y_array.append(nodes[i][NUMBER_OF_VALIDATOR])

host.set_xlabel("Node index")
host.set_ylabel("Leader")
par1.set_ylabel("Deposit")

p1, = host.plot(x_array, leader_y_array, label="Leader")
p2, = par1.plot(x_array, deposit_y_array, label="Deposit")
p3, = par2.plot(x_array, validator_y_array, label="Validator")

# par1.set_ylim(0, 4)
# par2.set_ylim(1, 65)

host.legend()

host.axis["left"].label.set_color(p1.get_color())
par1.axis["right"].label.set_color(p2.get_color())
par2.axis["right2"].label.set_color(p3.get_color())

plt.show()
