# %%
import numpy as np
import random
from math import *

# %%
NUMBER_OF_NODE = 10;
NUMBER_OF_VOTE = "vote"
POINT = "point"
NUMBER_OF_VALIDATOR = "validator"
NUMBER_OF_DEPOSIT = "deposit"
NODE = "node"
SPEED = "speed"
RANKING = "ranking"
NUMBER_OF_EPOCH = "epoch"

#init nodes
def init_nodes(number_of_node):
    nodes = []
    for i in range(number_of_node):
        nodes.append({})
        nodes[i][NODE] = i+1
        nodes[i][SPEED] = 0
        nodes[i][RANKING] = 0
        nodes[i][NUMBER_OF_DEPOSIT] = 0
        nodes[i][NUMBER_OF_VOTE] = 0
        nodes[i][NUMBER_OF_VALIDATOR] = 0
        nodes[i][NUMBER_OF_EPOCH] = 0
        nodes[i][POINT] = 0
    
    return nodes

# %%
#random speed of nodes
def random_nodes_speed(nodes):
    arr_speed = np.random.randint(low=5,high=10,size=len(nodes)).tolist()
    for i in range(len(arr_speed)):
        nodes[i][SPEED] = arr_speed[i]
    return arr_speed

# %%
#random number of epochs that masternode join in blockchain
def random_epochs_of_nodes(nodes):
    arr_epochs = np.random.randint(low=1,high=9000,size=len(nodes)).tolist()
    for i in range(len(arr_speed)):
        nodes[i][NUMBER_OF_EPOCH] = arr_speed[i]
    return arr_epochs

# %%
def deposit_votes(nodes):
    arr_deposit_vote = np.random.randint(low=50000,high=500000,size=len(nodes)).tolist()
    arr_deposit_vote = np.sort(arr_deposit_vote)[::-1]
    for i in range(len(arr_deposit_vote)):
        nodes[i][NUMBER_OF_DEPOSIT] = arr_deposit_vote[i]
    return arr_deposit_vote

# %%
# chose a leader node by voting
def vote_leader(nodes):
    
    #random array with length is number of canidate of leader
    arr_random = np.random.rand(len(nodes)).tolist()
    
    #select lead node
    index_of_leader = -1
    maximum = -1
    arr_leader = []
    for i in range(len(nodes)):
        multi = nodes[i][NUMBER_OF_DEPOSIT] * arr_random[i]
        arr_leader.append(multi)
        if multi > maximum:
            index_of_leader = i
            maximum = arr_leader[i]
    nodes[index_of_leader][NUMBER_OF_VOTE] += 1
    return index_of_leader

# %%
# Ranking for each masternode
def ranking(nodes, arr_deposit_vote, arr_speed):
    total_deposit = sum(arr_deposit_vote)

    total_vote = 2000  # Total voting in one epoch
    total_epoch = 9000  # Total epoch in blockchain
    speed_arg = sum(arr_speed)/len(nodes)
    a = 0.6
    b,c,d,e = 0.25, 0.1, 0, 0.35
    for i in range(len(arr_deposit_vote)):
        trust = b*nodes[i][NUMBER_OF_EPOCH]/total_epoch + c*(
                nodes[i][SPEED]/speed_arg) + d*(
                nodes[i][NUMBER_OF_VOTE]/total_vote) + e*(
                nodes[i][NUMBER_OF_VOTE]/nodes[i][NUMBER_OF_EPOCH]) + (1-b-c-d-e)*(
                nodes[i][NUMBER_OF_VALIDATOR]/nodes[i][NUMBER_OF_EPOCH])
        
        vote_arg_deposit = arr_deposit_vote[i]/total_deposit
        
        nodes[i][RANKING] = a*(vote_arg_deposit) + (1-a)*trust

# %%
# Random validator base on Ranking of each node
def random_validator(nodes, arr_deposit_vote, leader):
    point_arr = []
    index_of_validator = -1
    maximum = -1
    
    total = sum(arr_deposit_vote) - arr_deposit_vote[leader]
    mean = total/(len(nodes) - 1)
    
    arr_random = np.random.rand(len(nodes)-1).tolist()
    for i in range(len(arr_random)):
        nodes[i][POINT] = nodes[i][RANKING] * arr_random[i] * 1/mean
        if nodes[i][POINT] > maximum:
            maximum = nodes[i][POINT]
            if i != leader:
                index_of_validator = i
    nodes[index_of_validator][NUMBER_OF_VALIDATOR] += 1
    return index_of_validator

# %%
nodes = init_nodes(150)
arr_deposit_vote = deposit_votes(nodes)
arr_speed = random_nodes_speed(nodes)
arr_epochs = random_epochs_of_nodes(nodes)
ranking(nodes, arr_deposit_vote, arr_speed)
# leader = random_lead(nodes)
for i in range(2000):
    leader = vote_leader(nodes)
    validator = random_validator(nodes, arr_deposit_vote, leader)

# %%
from mpl_toolkits.axisartist.parasite_axes import HostAxes, ParasiteAxes
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(12, 9))

host = HostAxes(fig, [0.15, 0.1, 0.65, 0.8])
par1 = ParasiteAxes(host, sharex=host)
par2 = ParasiteAxes(host, sharex=host)
host.parasites.append(par1)
host.parasites.append(par2)

host.set_xlabel("Node index")
host.set_ylabel("Leader")

host.axis["right"].set_visible(False)
par1.axis["right"].set_visible(True)
par1.set_ylabel("Deposit")

par1.axis["right"].major_ticklabels.set_visible(True)
par1.axis["right"].label.set_visible(True)

par2.set_ylabel("Validator")
offset = (60, 0)
new_axisline = par2.get_grid_helper().new_fixed_axis
par2.axis["right2"] = new_axisline(loc="right", axes=par2, offset=offset)

fig.add_axes(host)

x_array = []
leader_y_array = []
deposit_y_array = []
validator_y_array = []
for i in range(len(nodes)):
    x_array.append(i)
    leader_y_array.append(nodes[i][NUMBER_OF_VOTE])
    deposit_y_array.append(nodes[i][NUMBER_OF_DEPOSIT])
    validator_y_array.append(nodes[i][NUMBER_OF_VALIDATOR])

host.set_xlabel("Node index")
host.set_ylabel("Leader")
par1.set_ylabel("Deposit")

p1, = host.plot(x_array, leader_y_array, label="Leader")
p2, = par1.plot(x_array, deposit_y_array, label="Deposit")
p3, = par2.plot(x_array, validator_y_array, label="Validator")

# par1.set_ylim(0, 4)
# par2.set_ylim(1, 65)

host.legend()

host.axis["left"].label.set_color(p1.get_color())
par1.axis["right"].label.set_color(p2.get_color())
par2.axis["right2"].label.set_color(p3.get_color())

plt.show()

# %%
from mpl_toolkits.axisartist.parasite_axes import HostAxes, ParasiteAxes
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(12, 9))

host = HostAxes(fig, [0.15, 0.1, 0.65, 0.8])
par1 = ParasiteAxes(host, sharex=host)
host.parasites.append(par1)

host.set_xlabel("Node index")
host.set_ylabel("Leader")

host.axis["right"].set_visible(False)
par1.axis["right"].set_visible(True)
par1.set_ylabel("Deposit")

par1.axis["right"].major_ticklabels.set_visible(True)
par1.axis["right"].label.set_visible(True)

fig.add_axes(host)

x_array = []
point_y_array = []
ranking_y_array = []
for i in range(len(nodes)):
    x_array.append(i)
    point_y_array.append(nodes[i][POINT])
    ranking_y_array.append(nodes[i][RANKING])


host.set_xlabel("Node index")
host.set_ylabel("Point")
par1.set_ylabel("Ranking")

p1, = host.plot(x_array, point_y_array, label="Point")
p2, = par1.plot(x_array, ranking_y_array, label="Ranking")

host.legend()

host.axis["left"].label.set_color(p1.get_color())
par1.axis["right"].label.set_color(p2.get_color())

plt.show()

# %%
nodes
# Out:
# [{'deposit': 497700,
#   'epoch': 8,
#   'node': 1,
#   'point': 9.874867931451831e-08,
#   'ranking': 0.05501048305569836,
#   'speed': 8,
#   'validator': 52,
#   'vote': 240},
#  {'deposit': 496409,
#   'epoch': 9,
#   'node': 2,
#   'point': 7.72705526941692e-09,
#   'ranking': 0.06094901110320654,
#   'speed': 9,
#   'validator': 141,
#   'vote': 212},
#  {'deposit': 490260,
#   'epoch': 8,
#   'node': 3,
#   'point': 1.0394308678011581e-07,
#   'ranking': 0.05490061351199859,
#   'speed': 8,
#   'validator': 19,
#   'vote': 216},
#  {'deposit': 477127,
#   'epoch': 5,
#   'node': 4,
#   'point': 7.30177769354427e-08,
#   'ranking': 0.03683389476461405,
#   'speed': 5,
#   'validator': 1,
#   'vote': 147},
#  {'deposit': 474781,
#   'epoch': 9,
#   'node': 5,
#   'point': 2.0597439742072587e-07,
#   'ranking': 0.06062962152106424,
#   'speed': 9,
#   'validator': 161,
#   'vote': 118},
#  {'deposit': 473113,
#   'epoch': 8,
#   'node': 6,
#   'point': 5.2507683800329997e-08,
#   'ranking': 0.054647396702076544,
#   'speed': 8,
#   'validator': 17,
#   'vote': 134},
#  {'deposit': 468024,
#   'epoch': 6,
#   'node': 7,
#   'point': 1.3548833483388398e-08,
#   'ranking': 0.04265705979123747,
#   'speed': 6,
#   'validator': 1,
#   'vote': 112},
#  {'deposit': 464228,
#   'epoch': 8,
#   'node': 8,
#   'point': 1.622659597625929e-07,
#   'ranking': 0.05451618824834368,
#   'speed': 8,
#   'validator': 21,
#   'vote': 87},
#  {'deposit': 458630,
#   'epoch': 5,
#   'node': 9,
#   'point': 6.248175394191973e-08,
#   'ranking': 0.03656074194877874,
#   'speed': 5,
#   'validator': 0,
#   'vote': 92},
#  {'deposit': 455413,
#   'epoch': 9,
#   'node': 10,
#   'point': 7.093514328926537e-08,
#   'ranking': 0.060343606289561924,
#   'speed': 9,
#   'validator': 166,
#   'vote': 76},
#  {'deposit': 452752,
#   'epoch': 5,
#   'node': 11,
#   'point': 2.6593880340667352e-08,
#   'ranking': 0.0364739391022912,
#   'speed': 5,
#   'validator': 0,
#   'vote': 70},
#  {'deposit': 451177,
#   'epoch': 5,
#   'node': 12,
#   'point': 9.327085741434904e-08,
#   'ranking': 0.03645068042872573,
#   'speed': 5,
#   'validator': 0,
#   'vote': 61},
#  {'deposit': 450099,
#   'epoch': 9,
#   'node': 13,
#   'point': 1.2789000542822056e-07,
#   'ranking': 0.0602651322633226,
#   'speed': 9,
#   'validator': 122,
#   'vote': 52},
#  {'deposit': 448348,
#   'epoch': 8,
#   'node': 14,
#   'point': 1.1268552450929288e-07,
#   'ranking': 0.05428168174915653,
#   'speed': 8,
#   'validator': 16,
#   'vote': 50},
#  {'deposit': 446659,
#   'epoch': 7,
#   'node': 15,
#   'point': 2.090901417611973e-08,
#   'ranking': 0.04829914681452129,
#   'speed': 7,
#   'validator': 0,
#   'vote': 48},
#  {'deposit': 444950,
#   'epoch': 5,
#   'node': 16,
#   'point': 9.497112278824418e-08,
#   'ranking': 0.03635872375552431,
#   'speed': 5,
#   'validator': 0,
#   'vote': 50},
#  {'deposit': 440694,
#   'epoch': 6,
#   'node': 17,
#   'point': 5.803009276268369e-08,
#   'ranking': 0.042253466427082255,
#   'speed': 6,
#   'validator': 0,
#   'vote': 41},
#  {'deposit': 438052,
#   'epoch': 5,
#   'node': 18,
#   'point': 2.6376085802640776e-08,
#   'ranking': 0.03625685814901342,
#   'speed': 5,
#   'validator': 0,
#   'vote': 25},
#  {'deposit': 435809,
#   'epoch': 7,
#   'node': 19,
#   'point': 1.194879134383429e-07,
#   'ranking': 0.04813892039662579,
#   'speed': 7,
#   'validator': 0,
#   'vote': 39},
#  {'deposit': 434374,
#   'epoch': 9,
#   'node': 20,
#   'point': 5.440795161297368e-08,
#   'ranking': 0.06003291471296252,
#   'speed': 9,
#   'validator': 140,
#   'vote': 22},
#  {'deposit': 429237,
#   'epoch': 6,
#   'node': 21,
#   'point': 8.604269353724278e-09,
#   'ranking': 0.042084276190231674,
#   'speed': 6,
#   'validator': 0,
#   'vote': 16},
#  {'deposit': 427955,
#   'epoch': 6,
#   'node': 22,
#   'point': 1.3815528407046894e-07,
#   'ranking': 0.04206534436831996,
#   'speed': 6,
#   'validator': 0,
#   'vote': 24},
#  {'deposit': 425775,
#   'epoch': 6,
#   'node': 23,
#   'point': 1.0611681801045847e-07,
#   'ranking': 0.042033151410622985,
#   'speed': 6,
#   'validator': 0,
#   'vote': 12},
#  {'deposit': 425115,
#   'epoch': 6,
#   'node': 24,
#   'point': 1.1956368996670892e-07,
#   'ranking': 0.04202340491884317,
#   'speed': 6,
#   'validator': 0,
#   'vote': 8},
#  {'deposit': 424851,
#   'epoch': 6,
#   'node': 25,
#   'point': 1.4266105161773825e-07,
#   'ranking': 0.04201950632213124,
#   'speed': 6,
#   'validator': 0,
#   'vote': 14},
#  {'deposit': 423496,
#   'epoch': 8,
#   'node': 26,
#   'point': 1.0177821329187551e-07,
#   'ranking': 0.05391468203141099,
#   'speed': 8,
#   'validator': 17,
#   'vote': 14},
#  {'deposit': 410491,
#   'epoch': 5,
#   'node': 27,
#   'point': 1.315060093639253e-07,
#   'ranking': 0.035849853512735265,
#   'speed': 5,
#   'validator': 0,
#   'vote': 3},
#  {'deposit': 410480,
#   'epoch': 7,
#   'node': 28,
#   'point': 1.5166854244982144e-07,
#   'ranking': 0.04776487662345756,
#   'speed': 7,
#   'validator': 1,
#   'vote': 2},
#  {'deposit': 404651,
#   'epoch': 5,
#   'node': 29,
#   'point': 1.1616127000689529e-07,
#   'ranking': 0.035763611827895656,
#   'speed': 5,
#   'validator': 0,
#   'vote': 6},
#  {'deposit': 395530,
#   'epoch': 6,
#   'node': 30,
#   'point': 1.2143109485586492e-08,
#   'ranking': 0.0415865110411069,
#   'speed': 6,
#   'validator': 0,
#   'vote': 2},
#  {'deposit': 393973,
#   'epoch': 6,
#   'node': 31,
#   'point': 4.250648801685333e-08,
#   'ranking': 0.0415635181809536,
#   'speed': 6,
#   'validator': 0,
#   'vote': 2},
#  {'deposit': 384180,
#   'epoch': 5,
#   'node': 32,
#   'point': 6.4045969774777635e-09,
#   'ranking': 0.03546130814119162,
#   'speed': 5,
#   'validator': 0,
#   'vote': 1},
#  {'deposit': 382955,
#   'epoch': 5,
#   'node': 33,
#   'point': 1.1376482723671762e-08,
#   'ranking': 0.0354432180617518,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 382843,
#   'epoch': 7,
#   'node': 34,
#   'point': 4.3038853507338446e-08,
#   'ranking': 0.04735674966388355,
#   'speed': 7,
#   'validator': 0,
#   'vote': 2},
#  {'deposit': 378089,
#   'epoch': 6,
#   'node': 35,
#   'point': 1.2441309434630853e-07,
#   'ranking': 0.0413289526121193,
#   'speed': 6,
#   'validator': 0,
#   'vote': 1},
#  {'deposit': 373902,
#   'epoch': 6,
#   'node': 36,
#   'point': 2.2474601070851285e-08,
#   'ranking': 0.0412671214589646,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 372937,
#   'epoch': 5,
#   'node': 37,
#   'point': 5.380983739272285e-08,
#   'ranking': 0.035295278130463584,
#   'speed': 5,
#   'validator': 0,
#   'vote': 1},
#  {'deposit': 372607,
#   'epoch': 8,
#   'node': 38,
#   'point': 1.418474272371942e-07,
#   'ranking': 0.05316318321295161,
#   'speed': 8,
#   'validator': 8,
#   'vote': 0},
#  {'deposit': 371418,
#   'epoch': 6,
#   'node': 39,
#   'point': 9.535457900132026e-08,
#   'ranking': 0.041230439208084196,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 369986,
#   'epoch': 7,
#   'node': 40,
#   'point': 1.3342457316668968e-07,
#   'ranking': 0.04716688505053032,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 367731,
#   'epoch': 9,
#   'node': 41,
#   'point': 1.4504655077419497e-07,
#   'ranking': 0.05904877008920122,
#   'speed': 9,
#   'validator': 109,
#   'vote': 0},
#  {'deposit': 365928,
#   'epoch': 9,
#   'node': 42,
#   'point': 5.619794938652918e-08,
#   'ranking': 0.05902214444574817,
#   'speed': 9,
#   'validator': 92,
#   'vote': 0},
#  {'deposit': 355582,
#   'epoch': 7,
#   'node': 43,
#   'point': 8.79797650133814e-08,
#   'ranking': 0.04695417525114168,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 352792,
#   'epoch': 7,
#   'node': 44,
#   'point': 1.4309522940457016e-07,
#   'ranking': 0.04691297417225426,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 352261,
#   'epoch': 6,
#   'node': 45,
#   'point': 4.4531703275919414e-08,
#   'ranking': 0.040947539900469065,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 350597,
#   'epoch': 6,
#   'node': 46,
#   'point': 5.942468688684126e-08,
#   'ranking': 0.04092296692725449,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 341912,
#   'epoch': 9,
#   'node': 47,
#   'point': 1.136214700904628e-07,
#   'ranking': 0.05866749028425708,
#   'speed': 9,
#   'validator': 106,
#   'vote': 0},
#  {'deposit': 335257,
#   'epoch': 7,
#   'node': 48,
#   'point': 2.282934217540018e-08,
#   'ranking': 0.04665402760655862,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 333040,
#   'epoch': 7,
#   'node': 49,
#   'point': 1.0089158751543434e-07,
#   'ranking': 0.046621288254625505,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 330479,
#   'epoch': 8,
#   'node': 50,
#   'point': 1.5160840125485664e-07,
#   'ranking': 0.05254106168916343,
#   'speed': 8,
#   'validator': 2,
#   'vote': 0},
#  {'deposit': 328167,
#   'epoch': 5,
#   'node': 51,
#   'point': 4.5899030132353625e-08,
#   'ranking': 0.03463414110473255,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 323741,
#   'epoch': 5,
#   'node': 52,
#   'point': 1.2322712084162436e-07,
#   'ranking': 0.03456878054016062,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 323400,
#   'epoch': 6,
#   'node': 53,
#   'point': 1.1575232914866388e-07,
#   'ranking': 0.04052133762886702,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 318738,
#   'epoch': 7,
#   'node': 54,
#   'point': 7.770614348320139e-08,
#   'ranking': 0.04641008473123919,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 315552,
#   'epoch': 5,
#   'node': 55,
#   'point': 1.2710066801288648e-07,
#   'ranking': 0.034447850205031924,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 312765,
#   'epoch': 6,
#   'node': 56,
#   'point': 1.3949461538761067e-07,
#   'ranking': 0.040364286204505856,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 312550,
#   'epoch': 6,
#   'node': 57,
#   'point': 1.0121476987972547e-07,
#   'ranking': 0.040361111210971516,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 310550,
#   'epoch': 5,
#   'node': 58,
#   'point': 1.6490951267379866e-08,
#   'ranking': 0.03437398361127033,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 310014,
#   'epoch': 9,
#   'node': 59,
#   'point': 1.5837527871598402e-08,
#   'ranking': 0.05819643938305608,
#   'speed': 9,
#   'validator': 75,
#   'vote': 0},
#  {'deposit': 308664,
#   'epoch': 5,
#   'node': 60,
#   'point': 8.929567361348663e-08,
#   'ranking': 0.034346132272638906,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 307236,
#   'epoch': 7,
#   'node': 61,
#   'point': 8.51115229063985e-08,
#   'ranking': 0.04624022996085817,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 303849,
#   'epoch': 9,
#   'node': 62,
#   'point': 1.6449060388684967e-07,
#   'ranking': 0.058105398289385504,
#   'speed': 9,
#   'validator': 69,
#   'vote': 0},
#  {'deposit': 303206,
#   'epoch': 7,
#   'node': 63,
#   'point': 5.7905130490889285e-08,
#   'ranking': 0.046180717291354124,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 302607,
#   'epoch': 6,
#   'node': 64,
#   'point': 9.155781447462769e-08,
#   'ranking': 0.04021427883556737,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 302314,
#   'epoch': 7,
#   'node': 65,
#   'point': 7.352797780854213e-08,
#   'ranking': 0.046167544760039585,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 300258,
#   'epoch': 6,
#   'node': 66,
#   'point': 5.3265930964236876e-08,
#   'ranking': 0.04017959018527829,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 293496,
#   'epoch': 7,
#   'node': 67,
#   'point': 9.942533465321769e-08,
#   'ranking': 0.04603732572289649,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 290516,
#   'epoch': 7,
#   'node': 68,
#   'point': 1.2523033414412727e-07,
#   'ranking': 0.04599331883576943,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 284583,
#   'epoch': 5,
#   'node': 69,
#   'point': 1.0311487349220667e-07,
#   'ranking': 0.033990518229381615,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 283747,
#   'epoch': 7,
#   'node': 70,
#   'point': 1.5801828624228156e-07,
#   'ranking': 0.04589335822537914,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 282984,
#   'epoch': 9,
#   'node': 71,
#   'point': 1.1299174717689716e-07,
#   'ranking': 0.05779727624243714,
#   'speed': 9,
#   'validator': 69,
#   'vote': 0},
#  {'deposit': 280808,
#   'epoch': 6,
#   'node': 72,
#   'point': 1.474026471318146e-07,
#   'ranking': 0.03989236402600939,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 279053,
#   'epoch': 6,
#   'node': 73,
#   'point': 2.8128013379587647e-08,
#   'ranking': 0.039866447218322144,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 278691,
#   'epoch': 7,
#   'node': 74,
#   'point': 6.283303658382966e-08,
#   'ranking': 0.045818694191381015,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 275259,
#   'epoch': 9,
#   'node': 75,
#   'point': 1.6945995880999643e-08,
#   'ranking': 0.0576831979863779,
#   'speed': 9,
#   'validator': 75,
#   'vote': 0},
#  {'deposit': 271004,
#   'epoch': 9,
#   'node': 76,
#   'point': 2.138398144163072e-07,
#   'ranking': 0.05762036264922165,
#   'speed': 9,
#   'validator': 82,
#   'vote': 0},
#  {'deposit': 267550,
#   'epoch': 9,
#   'node': 77,
#   'point': 1.5520132654085153e-07,
#   'ranking': 0.057569356008907266,
#   'speed': 9,
#   'validator': 62,
#   'vote': 0},
#  {'deposit': 266319,
#   'epoch': 7,
#   'node': 78,
#   'point': 3.563950689254679e-08,
#   'ranking': 0.04563599177274477,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 265984,
#   'epoch': 6,
#   'node': 79,
#   'point': 1.125432208259856e-07,
#   'ranking': 0.039673451913669944,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 264828,
#   'epoch': 7,
#   'node': 80,
#   'point': 1.741934554710873e-08,
#   'ranking': 0.04561397356176946,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 257409,
#   'epoch': 6,
#   'node': 81,
#   'point': 9.961199333306919e-08,
#   'ranking': 0.039546821357591244,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 256759,
#   'epoch': 5,
#   'node': 82,
#   'point': 4.887278960435134e-08,
#   'ranking': 0.03357962976380332,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 253702,
#   'epoch': 6,
#   'node': 83,
#   'point': 1.449544205053222e-07,
#   'ranking': 0.03949207856209459,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 253342,
#   'epoch': 8,
#   'node': 84,
#   'point': 1.382690460842716e-07,
#   'ranking': 0.05140194784610301,
#   'speed': 8,
#   'validator': 3,
#   'vote': 0},
#  {'deposit': 253018,
#   'epoch': 5,
#   'node': 85,
#   'point': 3.7716553238727765e-08,
#   'ranking': 0.03352438487630589,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 245707,
#   'epoch': 7,
#   'node': 86,
#   'point': 1.8534478463176693e-08,
#   'ranking': 0.04533160588097868,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 244063,
#   'epoch': 9,
#   'node': 87,
#   'point': 1.5203984254520272e-07,
#   'ranking': 0.05722251380825181,
#   'speed': 9,
#   'validator': 63,
#   'vote': 0},
#  {'deposit': 244033,
#   'epoch': 7,
#   'node': 88,
#   'point': 3.1930269914238484e-09,
#   'ranking': 0.04530688523364623,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 241765,
#   'epoch': 8,
#   'node': 89,
#   'point': 1.6053350572904372e-07,
#   'ranking': 0.051230985519837915,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 241153,
#   'epoch': 5,
#   'node': 90,
#   'point': 1.1729860363097078e-07,
#   'ranking': 0.03334916953544597,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 239828,
#   'epoch': 9,
#   'node': 91,
#   'point': 6.694120557869523e-09,
#   'ranking': 0.0571599738193313,
#   'speed': 9,
#   'validator': 50,
#   'vote': 0},
#  {'deposit': 238587,
#   'epoch': 7,
#   'node': 92,
#   'point': 1.4146890672719842e-07,
#   'ranking': 0.04522646190905094,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 230845,
#   'epoch': 8,
#   'node': 93,
#   'point': 1.3563230403702992e-07,
#   'ranking': 0.051069725383117284,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 227256,
#   'epoch': 5,
#   'node': 94,
#   'point': 7.896706750152233e-08,
#   'ranking': 0.03314394681383363,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 227169,
#   'epoch': 6,
#   'node': 95,
#   'point': 9.062045334687265e-08,
#   'ranking': 0.039100254825134094,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 222817,
#   'epoch': 6,
#   'node': 96,
#   'point': 8.8404411579272e-08,
#   'ranking': 0.039035987049034444,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 222015,
#   'epoch': 6,
#   'node': 97,
#   'point': 1.3155263729349402e-07,
#   'ranking': 0.039024143584780784,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 218923,
#   'epoch': 6,
#   'node': 98,
#   'point': 7.774552891870703e-08,
#   'ranking': 0.038978482747533516,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 215669,
#   'epoch': 6,
#   'node': 99,
#   'point': 4.6878673451673494e-08,
#   'ranking': 0.03893042958957665,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 213868,
#   'epoch': 9,
#   'node': 100,
#   'point': 1.598890753146133e-07,
#   'ranking': 0.056776611809325105,
#   'speed': 9,
#   'validator': 41,
#   'vote': 0},
#  {'deposit': 212922,
#   'epoch': 6,
#   'node': 101,
#   'point': 6.410579598441604e-09,
#   'ranking': 0.0388898635093961,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 211085,
#   'epoch': 6,
#   'node': 102,
#   'point': 7.545608813375838e-09,
#   'ranking': 0.038862735773942274,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 206457,
#   'epoch': 6,
#   'node': 103,
#   'point': 4.719983345855018e-08,
#   'ranking': 0.03879439219218924,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 201319,
#   'epoch': 6,
#   'node': 104,
#   'point': 5.119464306118661e-08,
#   'ranking': 0.038718517230424535,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 200139,
#   'epoch': 5,
#   'node': 105,
#   'point': 9.897270190187559e-08,
#   'ranking': 0.03274349890838918,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 194776,
#   'epoch': 9,
#   'node': 106,
#   'point': 2.2884238189000028e-08,
#   'ranking': 0.05649467238347616,
#   'speed': 9,
#   'validator': 60,
#   'vote': 0},
#  {'deposit': 194525,
#   'epoch': 5,
#   'node': 107,
#   'point': 2.567750183547601e-08,
#   'ranking': 0.03266059465861357,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 190632,
#   'epoch': 6,
#   'node': 108,
#   'point': 5.9331367877071076e-08,
#   'ranking': 0.038560697900650406,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 188082,
#   'epoch': 6,
#   'node': 109,
#   'point': 4.504660495989627e-08,
#   'ranking': 0.038523041000592013,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 186507,
#   'epoch': 9,
#   'node': 110,
#   'point': 1.2502485813616172e-07,
#   'ranking': 0.05637256065540447,
#   'speed': 9,
#   'validator': 28,
#   'vote': 0},
#  {'deposit': 182919,
#   'epoch': 5,
#   'node': 111,
#   'point': 9.209999657452223e-08,
#   'ranking': 0.03248920407740664,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 179051,
#   'epoch': 6,
#   'node': 112,
#   'point': 5.97988952272949e-08,
#   'ranking': 0.038389676504738166,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 173540,
#   'epoch': 6,
#   'node': 113,
#   'point': 3.974943313194927e-08,
#   'ranking': 0.03830829329837668,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 171960,
#   'epoch': 5,
#   'node': 114,
#   'point': 5.5073344777282825e-08,
#   'ranking': 0.032327368011626285,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 171009,
#   'epoch': 5,
#   'node': 115,
#   'point': 3.535408114463967e-08,
#   'ranking': 0.032313324203016275,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 167420,
#   'epoch': 8,
#   'node': 116,
#   'point': 9.12524520239196e-08,
#   'ranking': 0.05013310229048849,
#   'speed': 8,
#   'validator': 1,
#   'vote': 0},
#  {'deposit': 159748,
#   'epoch': 7,
#   'node': 117,
#   'point': 7.309065797635615e-08,
#   'ranking': 0.044062213931128025,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 154862,
#   'epoch': 7,
#   'node': 118,
#   'point': 9.150219059455026e-08,
#   'ranking': 0.04399006035713379,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 144450,
#   'epoch': 6,
#   'node': 119,
#   'point': 6.620694206540748e-08,
#   'ranking': 0.037878709289475274,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 137327,
#   'epoch': 9,
#   'node': 120,
#   'point': 2.0134765370124354e-07,
#   'ranking': 0.0556462993436901,
#   'speed': 9,
#   'validator': 32,
#   'vote': 0},
#  {'deposit': 135116,
#   'epoch': 7,
#   'node': 121,
#   'point': 5.0142258177109576e-08,
#   'ranking': 0.04369846304397576,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 127582,
#   'epoch': 7,
#   'node': 122,
#   'point': 7.044293736299569e-08,
#   'ranking': 0.04358720536356795,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 125565,
#   'epoch': 5,
#   'node': 123,
#   'point': 2.8926755698903064e-08,
#   'ranking': 0.03164223394174039,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 125383,
#   'epoch': 5,
#   'node': 124,
#   'point': 3.195663796790022e-08,
#   'ranking': 0.03163954627279505,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 121150,
#   'epoch': 7,
#   'node': 125,
#   'point': 1.5302010678138357e-07,
#   'ranking': 0.04349222137095008,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 120555,
#   'epoch': 8,
#   'node': 126,
#   'point': 1.6672786018423126e-07,
#   'ranking': 0.04944102753706243,
#   'speed': 8,
#   'validator': 1,
#   'vote': 0},
#  {'deposit': 120131,
#   'epoch': 7,
#   'node': 127,
#   'point': 1.3648067560622506e-07,
#   'ranking': 0.043477173378338514,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 116314,
#   'epoch': 5,
#   'node': 128,
#   'point': 3.257561050709234e-08,
#   'ranking': 0.031505620615293266,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 115999,
#   'epoch': 7,
#   'node': 129,
#   'point': 7.42508768551103e-08,
#   'ranking': 0.04341615443283214,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 110313,
#   'epoch': 9,
#   'node': 130,
#   'point': 6.602391298696839e-09,
#   'ranking': 0.055247372481659764,
#   'speed': 9,
#   'validator': 29,
#   'vote': 0},
#  {'deposit': 107523,
#   'epoch': 9,
#   'node': 131,
#   'point': 1.9844834119492226e-07,
#   'ranking': 0.05520617140277235,
#   'speed': 9,
#   'validator': 22,
#   'vote': 0},
#  {'deposit': 104490,
#   'epoch': 9,
#   'node': 132,
#   'point': 1.362832427816264e-07,
#   'ranking': 0.055161381842820545,
#   'speed': 9,
#   'validator': 29,
#   'vote': 0},
#  {'deposit': 100735,
#   'epoch': 9,
#   'node': 133,
#   'point': 9.271998934695504e-08,
#   'ranking': 0.055105930211558095,
#   'speed': 9,
#   'validator': 16,
#   'vote': 0},
#  {'deposit': 91486,
#   'epoch': 8,
#   'node': 134,
#   'point': 4.738877608333415e-08,
#   'ranking': 0.04901175364380857,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 86917,
#   'epoch': 8,
#   'node': 135,
#   'point': 1.5297081364412963e-07,
#   'ranking': 0.048944281339351005,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 86325,
#   'epoch': 5,
#   'node': 136,
#   'point': 5.951196321734957e-08,
#   'ranking': 0.03106276070319481,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 83536,
#   'epoch': 7,
#   'node': 137,
#   'point': 1.2137073647117717e-07,
#   'ranking': 0.04293675994397114,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 83526,
#   'epoch': 6,
#   'node': 138,
#   'point': 8.179992960938323e-08,
#   'ranking': 0.03697901949372728,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 79355,
#   'epoch': 7,
#   'node': 139,
#   'point': 1.1956675397805132e-07,
#   'ranking': 0.04287501739528717,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 79313,
#   'epoch': 6,
#   'node': 140,
#   'point': 1.0395556819108935e-07,
#   'ranking': 0.03691680438786611,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 74785,
#   'epoch': 5,
#   'node': 141,
#   'point': 5.301295300487374e-08,
#   'ranking': 0.03089234477116586,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 70668,
#   'epoch': 6,
#   'node': 142,
#   'point': 9.139583143015436e-08,
#   'ranking': 0.036789140112962276,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 65608,
#   'epoch': 8,
#   'node': 143,
#   'point': 1.1604491569094497e-07,
#   'ranking': 0.04862960256156895,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 63642,
#   'epoch': 8,
#   'node': 144,
#   'point': 1.784342075678748e-07,
#   'ranking': 0.04860056982999452,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 62878,
#   'epoch': 8,
#   'node': 145,
#   'point': 5.1985308369598026e-08,
#   'ranking': 0.048589287527388794,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 59577,
#   'epoch': 6,
#   'node': 146,
#   'point': 1.1167041447997913e-07,
#   'ranking': 0.03662535474882596,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 58229,
#   'epoch': 5,
#   'node': 147,
#   'point': 1.0839341581352853e-07,
#   'ranking': 0.030647855501610286,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 57242,
#   'epoch': 8,
#   'node': 148,
#   'point': 4.100671889614125e-08,
#   'ranking': 0.04850605839455385,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 53583,
#   'epoch': 7,
#   'node': 149,
#   'point': 1.0443400305357399e-07,
#   'ranking': 0.04249443165869704,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 52738,
#   'epoch': 5,
#   'node': 150,
#   'point': 0,
#   'ranking': 0.030566767643484552,
#   'speed': 5,
#   'validator': 1,
#   'vote': 0}]

# %%
node_none = []
for i in range(len(nodes)):
    if nodes[i][NUMBER_OF_VALIDATOR] == 0:
        node_none.append(nodes[i])

# %%
node_none
# Out:
# [{'deposit': 458630,
#   'epoch': 5,
#   'node': 9,
#   'point': 6.248175394191973e-08,
#   'ranking': 0.03656074194877874,
#   'speed': 5,
#   'validator': 0,
#   'vote': 92},
#  {'deposit': 452752,
#   'epoch': 5,
#   'node': 11,
#   'point': 2.6593880340667352e-08,
#   'ranking': 0.0364739391022912,
#   'speed': 5,
#   'validator': 0,
#   'vote': 70},
#  {'deposit': 451177,
#   'epoch': 5,
#   'node': 12,
#   'point': 9.327085741434904e-08,
#   'ranking': 0.03645068042872573,
#   'speed': 5,
#   'validator': 0,
#   'vote': 61},
#  {'deposit': 446659,
#   'epoch': 7,
#   'node': 15,
#   'point': 2.090901417611973e-08,
#   'ranking': 0.04829914681452129,
#   'speed': 7,
#   'validator': 0,
#   'vote': 48},
#  {'deposit': 444950,
#   'epoch': 5,
#   'node': 16,
#   'point': 9.497112278824418e-08,
#   'ranking': 0.03635872375552431,
#   'speed': 5,
#   'validator': 0,
#   'vote': 50},
#  {'deposit': 440694,
#   'epoch': 6,
#   'node': 17,
#   'point': 5.803009276268369e-08,
#   'ranking': 0.042253466427082255,
#   'speed': 6,
#   'validator': 0,
#   'vote': 41},
#  {'deposit': 438052,
#   'epoch': 5,
#   'node': 18,
#   'point': 2.6376085802640776e-08,
#   'ranking': 0.03625685814901342,
#   'speed': 5,
#   'validator': 0,
#   'vote': 25},
#  {'deposit': 435809,
#   'epoch': 7,
#   'node': 19,
#   'point': 1.194879134383429e-07,
#   'ranking': 0.04813892039662579,
#   'speed': 7,
#   'validator': 0,
#   'vote': 39},
#  {'deposit': 429237,
#   'epoch': 6,
#   'node': 21,
#   'point': 8.604269353724278e-09,
#   'ranking': 0.042084276190231674,
#   'speed': 6,
#   'validator': 0,
#   'vote': 16},
#  {'deposit': 427955,
#   'epoch': 6,
#   'node': 22,
#   'point': 1.3815528407046894e-07,
#   'ranking': 0.04206534436831996,
#   'speed': 6,
#   'validator': 0,
#   'vote': 24},
#  {'deposit': 425775,
#   'epoch': 6,
#   'node': 23,
#   'point': 1.0611681801045847e-07,
#   'ranking': 0.042033151410622985,
#   'speed': 6,
#   'validator': 0,
#   'vote': 12},
#  {'deposit': 425115,
#   'epoch': 6,
#   'node': 24,
#   'point': 1.1956368996670892e-07,
#   'ranking': 0.04202340491884317,
#   'speed': 6,
#   'validator': 0,
#   'vote': 8},
#  {'deposit': 424851,
#   'epoch': 6,
#   'node': 25,
#   'point': 1.4266105161773825e-07,
#   'ranking': 0.04201950632213124,
#   'speed': 6,
#   'validator': 0,
#   'vote': 14},
#  {'deposit': 410491,
#   'epoch': 5,
#   'node': 27,
#   'point': 1.315060093639253e-07,
#   'ranking': 0.035849853512735265,
#   'speed': 5,
#   'validator': 0,
#   'vote': 3},
#  {'deposit': 404651,
#   'epoch': 5,
#   'node': 29,
#   'point': 1.1616127000689529e-07,
#   'ranking': 0.035763611827895656,
#   'speed': 5,
#   'validator': 0,
#   'vote': 6},
#  {'deposit': 395530,
#   'epoch': 6,
#   'node': 30,
#   'point': 1.2143109485586492e-08,
#   'ranking': 0.0415865110411069,
#   'speed': 6,
#   'validator': 0,
#   'vote': 2},
#  {'deposit': 393973,
#   'epoch': 6,
#   'node': 31,
#   'point': 4.250648801685333e-08,
#   'ranking': 0.0415635181809536,
#   'speed': 6,
#   'validator': 0,
#   'vote': 2},
#  {'deposit': 384180,
#   'epoch': 5,
#   'node': 32,
#   'point': 6.4045969774777635e-09,
#   'ranking': 0.03546130814119162,
#   'speed': 5,
#   'validator': 0,
#   'vote': 1},
#  {'deposit': 382955,
#   'epoch': 5,
#   'node': 33,
#   'point': 1.1376482723671762e-08,
#   'ranking': 0.0354432180617518,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 382843,
#   'epoch': 7,
#   'node': 34,
#   'point': 4.3038853507338446e-08,
#   'ranking': 0.04735674966388355,
#   'speed': 7,
#   'validator': 0,
#   'vote': 2},
#  {'deposit': 378089,
#   'epoch': 6,
#   'node': 35,
#   'point': 1.2441309434630853e-07,
#   'ranking': 0.0413289526121193,
#   'speed': 6,
#   'validator': 0,
#   'vote': 1},
#  {'deposit': 373902,
#   'epoch': 6,
#   'node': 36,
#   'point': 2.2474601070851285e-08,
#   'ranking': 0.0412671214589646,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 372937,
#   'epoch': 5,
#   'node': 37,
#   'point': 5.380983739272285e-08,
#   'ranking': 0.035295278130463584,
#   'speed': 5,
#   'validator': 0,
#   'vote': 1},
#  {'deposit': 371418,
#   'epoch': 6,
#   'node': 39,
#   'point': 9.535457900132026e-08,
#   'ranking': 0.041230439208084196,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 369986,
#   'epoch': 7,
#   'node': 40,
#   'point': 1.3342457316668968e-07,
#   'ranking': 0.04716688505053032,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 355582,
#   'epoch': 7,
#   'node': 43,
#   'point': 8.79797650133814e-08,
#   'ranking': 0.04695417525114168,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 352792,
#   'epoch': 7,
#   'node': 44,
#   'point': 1.4309522940457016e-07,
#   'ranking': 0.04691297417225426,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 352261,
#   'epoch': 6,
#   'node': 45,
#   'point': 4.4531703275919414e-08,
#   'ranking': 0.040947539900469065,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 350597,
#   'epoch': 6,
#   'node': 46,
#   'point': 5.942468688684126e-08,
#   'ranking': 0.04092296692725449,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 335257,
#   'epoch': 7,
#   'node': 48,
#   'point': 2.282934217540018e-08,
#   'ranking': 0.04665402760655862,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 333040,
#   'epoch': 7,
#   'node': 49,
#   'point': 1.0089158751543434e-07,
#   'ranking': 0.046621288254625505,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 328167,
#   'epoch': 5,
#   'node': 51,
#   'point': 4.5899030132353625e-08,
#   'ranking': 0.03463414110473255,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 323741,
#   'epoch': 5,
#   'node': 52,
#   'point': 1.2322712084162436e-07,
#   'ranking': 0.03456878054016062,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 323400,
#   'epoch': 6,
#   'node': 53,
#   'point': 1.1575232914866388e-07,
#   'ranking': 0.04052133762886702,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 318738,
#   'epoch': 7,
#   'node': 54,
#   'point': 7.770614348320139e-08,
#   'ranking': 0.04641008473123919,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 315552,
#   'epoch': 5,
#   'node': 55,
#   'point': 1.2710066801288648e-07,
#   'ranking': 0.034447850205031924,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 312765,
#   'epoch': 6,
#   'node': 56,
#   'point': 1.3949461538761067e-07,
#   'ranking': 0.040364286204505856,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 312550,
#   'epoch': 6,
#   'node': 57,
#   'point': 1.0121476987972547e-07,
#   'ranking': 0.040361111210971516,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 310550,
#   'epoch': 5,
#   'node': 58,
#   'point': 1.6490951267379866e-08,
#   'ranking': 0.03437398361127033,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 308664,
#   'epoch': 5,
#   'node': 60,
#   'point': 8.929567361348663e-08,
#   'ranking': 0.034346132272638906,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 307236,
#   'epoch': 7,
#   'node': 61,
#   'point': 8.51115229063985e-08,
#   'ranking': 0.04624022996085817,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 303206,
#   'epoch': 7,
#   'node': 63,
#   'point': 5.7905130490889285e-08,
#   'ranking': 0.046180717291354124,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 302607,
#   'epoch': 6,
#   'node': 64,
#   'point': 9.155781447462769e-08,
#   'ranking': 0.04021427883556737,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 302314,
#   'epoch': 7,
#   'node': 65,
#   'point': 7.352797780854213e-08,
#   'ranking': 0.046167544760039585,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 300258,
#   'epoch': 6,
#   'node': 66,
#   'point': 5.3265930964236876e-08,
#   'ranking': 0.04017959018527829,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 293496,
#   'epoch': 7,
#   'node': 67,
#   'point': 9.942533465321769e-08,
#   'ranking': 0.04603732572289649,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 290516,
#   'epoch': 7,
#   'node': 68,
#   'point': 1.2523033414412727e-07,
#   'ranking': 0.04599331883576943,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 284583,
#   'epoch': 5,
#   'node': 69,
#   'point': 1.0311487349220667e-07,
#   'ranking': 0.033990518229381615,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 283747,
#   'epoch': 7,
#   'node': 70,
#   'point': 1.5801828624228156e-07,
#   'ranking': 0.04589335822537914,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 280808,
#   'epoch': 6,
#   'node': 72,
#   'point': 1.474026471318146e-07,
#   'ranking': 0.03989236402600939,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 279053,
#   'epoch': 6,
#   'node': 73,
#   'point': 2.8128013379587647e-08,
#   'ranking': 0.039866447218322144,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 278691,
#   'epoch': 7,
#   'node': 74,
#   'point': 6.283303658382966e-08,
#   'ranking': 0.045818694191381015,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 266319,
#   'epoch': 7,
#   'node': 78,
#   'point': 3.563950689254679e-08,
#   'ranking': 0.04563599177274477,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 265984,
#   'epoch': 6,
#   'node': 79,
#   'point': 1.125432208259856e-07,
#   'ranking': 0.039673451913669944,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 264828,
#   'epoch': 7,
#   'node': 80,
#   'point': 1.741934554710873e-08,
#   'ranking': 0.04561397356176946,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 257409,
#   'epoch': 6,
#   'node': 81,
#   'point': 9.961199333306919e-08,
#   'ranking': 0.039546821357591244,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 256759,
#   'epoch': 5,
#   'node': 82,
#   'point': 4.887278960435134e-08,
#   'ranking': 0.03357962976380332,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 253702,
#   'epoch': 6,
#   'node': 83,
#   'point': 1.449544205053222e-07,
#   'ranking': 0.03949207856209459,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 253018,
#   'epoch': 5,
#   'node': 85,
#   'point': 3.7716553238727765e-08,
#   'ranking': 0.03352438487630589,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 245707,
#   'epoch': 7,
#   'node': 86,
#   'point': 1.8534478463176693e-08,
#   'ranking': 0.04533160588097868,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 244033,
#   'epoch': 7,
#   'node': 88,
#   'point': 3.1930269914238484e-09,
#   'ranking': 0.04530688523364623,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 241765,
#   'epoch': 8,
#   'node': 89,
#   'point': 1.6053350572904372e-07,
#   'ranking': 0.051230985519837915,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 241153,
#   'epoch': 5,
#   'node': 90,
#   'point': 1.1729860363097078e-07,
#   'ranking': 0.03334916953544597,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 238587,
#   'epoch': 7,
#   'node': 92,
#   'point': 1.4146890672719842e-07,
#   'ranking': 0.04522646190905094,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 230845,
#   'epoch': 8,
#   'node': 93,
#   'point': 1.3563230403702992e-07,
#   'ranking': 0.051069725383117284,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 227256,
#   'epoch': 5,
#   'node': 94,
#   'point': 7.896706750152233e-08,
#   'ranking': 0.03314394681383363,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 227169,
#   'epoch': 6,
#   'node': 95,
#   'point': 9.062045334687265e-08,
#   'ranking': 0.039100254825134094,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 222817,
#   'epoch': 6,
#   'node': 96,
#   'point': 8.8404411579272e-08,
#   'ranking': 0.039035987049034444,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 222015,
#   'epoch': 6,
#   'node': 97,
#   'point': 1.3155263729349402e-07,
#   'ranking': 0.039024143584780784,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 218923,
#   'epoch': 6,
#   'node': 98,
#   'point': 7.774552891870703e-08,
#   'ranking': 0.038978482747533516,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 215669,
#   'epoch': 6,
#   'node': 99,
#   'point': 4.6878673451673494e-08,
#   'ranking': 0.03893042958957665,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 212922,
#   'epoch': 6,
#   'node': 101,
#   'point': 6.410579598441604e-09,
#   'ranking': 0.0388898635093961,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 211085,
#   'epoch': 6,
#   'node': 102,
#   'point': 7.545608813375838e-09,
#   'ranking': 0.038862735773942274,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 206457,
#   'epoch': 6,
#   'node': 103,
#   'point': 4.719983345855018e-08,
#   'ranking': 0.03879439219218924,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 201319,
#   'epoch': 6,
#   'node': 104,
#   'point': 5.119464306118661e-08,
#   'ranking': 0.038718517230424535,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 200139,
#   'epoch': 5,
#   'node': 105,
#   'point': 9.897270190187559e-08,
#   'ranking': 0.03274349890838918,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 194525,
#   'epoch': 5,
#   'node': 107,
#   'point': 2.567750183547601e-08,
#   'ranking': 0.03266059465861357,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 190632,
#   'epoch': 6,
#   'node': 108,
#   'point': 5.9331367877071076e-08,
#   'ranking': 0.038560697900650406,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 188082,
#   'epoch': 6,
#   'node': 109,
#   'point': 4.504660495989627e-08,
#   'ranking': 0.038523041000592013,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 182919,
#   'epoch': 5,
#   'node': 111,
#   'point': 9.209999657452223e-08,
#   'ranking': 0.03248920407740664,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 179051,
#   'epoch': 6,
#   'node': 112,
#   'point': 5.97988952272949e-08,
#   'ranking': 0.038389676504738166,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 173540,
#   'epoch': 6,
#   'node': 113,
#   'point': 3.974943313194927e-08,
#   'ranking': 0.03830829329837668,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 171960,
#   'epoch': 5,
#   'node': 114,
#   'point': 5.5073344777282825e-08,
#   'ranking': 0.032327368011626285,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 171009,
#   'epoch': 5,
#   'node': 115,
#   'point': 3.535408114463967e-08,
#   'ranking': 0.032313324203016275,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 159748,
#   'epoch': 7,
#   'node': 117,
#   'point': 7.309065797635615e-08,
#   'ranking': 0.044062213931128025,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 154862,
#   'epoch': 7,
#   'node': 118,
#   'point': 9.150219059455026e-08,
#   'ranking': 0.04399006035713379,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 144450,
#   'epoch': 6,
#   'node': 119,
#   'point': 6.620694206540748e-08,
#   'ranking': 0.037878709289475274,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 135116,
#   'epoch': 7,
#   'node': 121,
#   'point': 5.0142258177109576e-08,
#   'ranking': 0.04369846304397576,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 127582,
#   'epoch': 7,
#   'node': 122,
#   'point': 7.044293736299569e-08,
#   'ranking': 0.04358720536356795,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 125565,
#   'epoch': 5,
#   'node': 123,
#   'point': 2.8926755698903064e-08,
#   'ranking': 0.03164223394174039,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 125383,
#   'epoch': 5,
#   'node': 124,
#   'point': 3.195663796790022e-08,
#   'ranking': 0.03163954627279505,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 121150,
#   'epoch': 7,
#   'node': 125,
#   'point': 1.5302010678138357e-07,
#   'ranking': 0.04349222137095008,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 120131,
#   'epoch': 7,
#   'node': 127,
#   'point': 1.3648067560622506e-07,
#   'ranking': 0.043477173378338514,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 116314,
#   'epoch': 5,
#   'node': 128,
#   'point': 3.257561050709234e-08,
#   'ranking': 0.031505620615293266,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 115999,
#   'epoch': 7,
#   'node': 129,
#   'point': 7.42508768551103e-08,
#   'ranking': 0.04341615443283214,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 91486,
#   'epoch': 8,
#   'node': 134,
#   'point': 4.738877608333415e-08,
#   'ranking': 0.04901175364380857,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 86917,
#   'epoch': 8,
#   'node': 135,
#   'point': 1.5297081364412963e-07,
#   'ranking': 0.048944281339351005,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 86325,
#   'epoch': 5,
#   'node': 136,
#   'point': 5.951196321734957e-08,
#   'ranking': 0.03106276070319481,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 83536,
#   'epoch': 7,
#   'node': 137,
#   'point': 1.2137073647117717e-07,
#   'ranking': 0.04293675994397114,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 83526,
#   'epoch': 6,
#   'node': 138,
#   'point': 8.179992960938323e-08,
#   'ranking': 0.03697901949372728,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 79355,
#   'epoch': 7,
#   'node': 139,
#   'point': 1.1956675397805132e-07,
#   'ranking': 0.04287501739528717,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 79313,
#   'epoch': 6,
#   'node': 140,
#   'point': 1.0395556819108935e-07,
#   'ranking': 0.03691680438786611,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 74785,
#   'epoch': 5,
#   'node': 141,
#   'point': 5.301295300487374e-08,
#   'ranking': 0.03089234477116586,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 70668,
#   'epoch': 6,
#   'node': 142,
#   'point': 9.139583143015436e-08,
#   'ranking': 0.036789140112962276,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 65608,
#   'epoch': 8,
#   'node': 143,
#   'point': 1.1604491569094497e-07,
#   'ranking': 0.04862960256156895,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 63642,
#   'epoch': 8,
#   'node': 144,
#   'point': 1.784342075678748e-07,
#   'ranking': 0.04860056982999452,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 62878,
#   'epoch': 8,
#   'node': 145,
#   'point': 5.1985308369598026e-08,
#   'ranking': 0.048589287527388794,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 59577,
#   'epoch': 6,
#   'node': 146,
#   'point': 1.1167041447997913e-07,
#   'ranking': 0.03662535474882596,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 58229,
#   'epoch': 5,
#   'node': 147,
#   'point': 1.0839341581352853e-07,
#   'ranking': 0.030647855501610286,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 57242,
#   'epoch': 8,
#   'node': 148,
#   'point': 4.100671889614125e-08,
#   'ranking': 0.04850605839455385,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 53583,
#   'epoch': 7,
#   'node': 149,
#   'point': 1.0443400305357399e-07,
#   'ranking': 0.04249443165869704,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0}]

# %%
len(node_none)
# Out:
# 111

# %%
nodes
# Out:
# [{'deposit': 497700,
#   'epoch': 8,
#   'node': 1,
#   'point': 9.874867931451831e-08,
#   'ranking': 0.05501048305569836,
#   'speed': 8,
#   'validator': 52,
#   'vote': 240},
#  {'deposit': 496409,
#   'epoch': 9,
#   'node': 2,
#   'point': 7.72705526941692e-09,
#   'ranking': 0.06094901110320654,
#   'speed': 9,
#   'validator': 141,
#   'vote': 212},
#  {'deposit': 490260,
#   'epoch': 8,
#   'node': 3,
#   'point': 1.0394308678011581e-07,
#   'ranking': 0.05490061351199859,
#   'speed': 8,
#   'validator': 19,
#   'vote': 216},
#  {'deposit': 477127,
#   'epoch': 5,
#   'node': 4,
#   'point': 7.30177769354427e-08,
#   'ranking': 0.03683389476461405,
#   'speed': 5,
#   'validator': 1,
#   'vote': 147},
#  {'deposit': 474781,
#   'epoch': 9,
#   'node': 5,
#   'point': 2.0597439742072587e-07,
#   'ranking': 0.06062962152106424,
#   'speed': 9,
#   'validator': 161,
#   'vote': 118},
#  {'deposit': 473113,
#   'epoch': 8,
#   'node': 6,
#   'point': 5.2507683800329997e-08,
#   'ranking': 0.054647396702076544,
#   'speed': 8,
#   'validator': 17,
#   'vote': 134},
#  {'deposit': 468024,
#   'epoch': 6,
#   'node': 7,
#   'point': 1.3548833483388398e-08,
#   'ranking': 0.04265705979123747,
#   'speed': 6,
#   'validator': 1,
#   'vote': 112},
#  {'deposit': 464228,
#   'epoch': 8,
#   'node': 8,
#   'point': 1.622659597625929e-07,
#   'ranking': 0.05451618824834368,
#   'speed': 8,
#   'validator': 21,
#   'vote': 87},
#  {'deposit': 458630,
#   'epoch': 5,
#   'node': 9,
#   'point': 6.248175394191973e-08,
#   'ranking': 0.03656074194877874,
#   'speed': 5,
#   'validator': 0,
#   'vote': 92},
#  {'deposit': 455413,
#   'epoch': 9,
#   'node': 10,
#   'point': 7.093514328926537e-08,
#   'ranking': 0.060343606289561924,
#   'speed': 9,
#   'validator': 166,
#   'vote': 76},
#  {'deposit': 452752,
#   'epoch': 5,
#   'node': 11,
#   'point': 2.6593880340667352e-08,
#   'ranking': 0.0364739391022912,
#   'speed': 5,
#   'validator': 0,
#   'vote': 70},
#  {'deposit': 451177,
#   'epoch': 5,
#   'node': 12,
#   'point': 9.327085741434904e-08,
#   'ranking': 0.03645068042872573,
#   'speed': 5,
#   'validator': 0,
#   'vote': 61},
#  {'deposit': 450099,
#   'epoch': 9,
#   'node': 13,
#   'point': 1.2789000542822056e-07,
#   'ranking': 0.0602651322633226,
#   'speed': 9,
#   'validator': 122,
#   'vote': 52},
#  {'deposit': 448348,
#   'epoch': 8,
#   'node': 14,
#   'point': 1.1268552450929288e-07,
#   'ranking': 0.05428168174915653,
#   'speed': 8,
#   'validator': 16,
#   'vote': 50},
#  {'deposit': 446659,
#   'epoch': 7,
#   'node': 15,
#   'point': 2.090901417611973e-08,
#   'ranking': 0.04829914681452129,
#   'speed': 7,
#   'validator': 0,
#   'vote': 48},
#  {'deposit': 444950,
#   'epoch': 5,
#   'node': 16,
#   'point': 9.497112278824418e-08,
#   'ranking': 0.03635872375552431,
#   'speed': 5,
#   'validator': 0,
#   'vote': 50},
#  {'deposit': 440694,
#   'epoch': 6,
#   'node': 17,
#   'point': 5.803009276268369e-08,
#   'ranking': 0.042253466427082255,
#   'speed': 6,
#   'validator': 0,
#   'vote': 41},
#  {'deposit': 438052,
#   'epoch': 5,
#   'node': 18,
#   'point': 2.6376085802640776e-08,
#   'ranking': 0.03625685814901342,
#   'speed': 5,
#   'validator': 0,
#   'vote': 25},
#  {'deposit': 435809,
#   'epoch': 7,
#   'node': 19,
#   'point': 1.194879134383429e-07,
#   'ranking': 0.04813892039662579,
#   'speed': 7,
#   'validator': 0,
#   'vote': 39},
#  {'deposit': 434374,
#   'epoch': 9,
#   'node': 20,
#   'point': 5.440795161297368e-08,
#   'ranking': 0.06003291471296252,
#   'speed': 9,
#   'validator': 140,
#   'vote': 22},
#  {'deposit': 429237,
#   'epoch': 6,
#   'node': 21,
#   'point': 8.604269353724278e-09,
#   'ranking': 0.042084276190231674,
#   'speed': 6,
#   'validator': 0,
#   'vote': 16},
#  {'deposit': 427955,
#   'epoch': 6,
#   'node': 22,
#   'point': 1.3815528407046894e-07,
#   'ranking': 0.04206534436831996,
#   'speed': 6,
#   'validator': 0,
#   'vote': 24},
#  {'deposit': 425775,
#   'epoch': 6,
#   'node': 23,
#   'point': 1.0611681801045847e-07,
#   'ranking': 0.042033151410622985,
#   'speed': 6,
#   'validator': 0,
#   'vote': 12},
#  {'deposit': 425115,
#   'epoch': 6,
#   'node': 24,
#   'point': 1.1956368996670892e-07,
#   'ranking': 0.04202340491884317,
#   'speed': 6,
#   'validator': 0,
#   'vote': 8},
#  {'deposit': 424851,
#   'epoch': 6,
#   'node': 25,
#   'point': 1.4266105161773825e-07,
#   'ranking': 0.04201950632213124,
#   'speed': 6,
#   'validator': 0,
#   'vote': 14},
#  {'deposit': 423496,
#   'epoch': 8,
#   'node': 26,
#   'point': 1.0177821329187551e-07,
#   'ranking': 0.05391468203141099,
#   'speed': 8,
#   'validator': 17,
#   'vote': 14},
#  {'deposit': 410491,
#   'epoch': 5,
#   'node': 27,
#   'point': 1.315060093639253e-07,
#   'ranking': 0.035849853512735265,
#   'speed': 5,
#   'validator': 0,
#   'vote': 3},
#  {'deposit': 410480,
#   'epoch': 7,
#   'node': 28,
#   'point': 1.5166854244982144e-07,
#   'ranking': 0.04776487662345756,
#   'speed': 7,
#   'validator': 1,
#   'vote': 2},
#  {'deposit': 404651,
#   'epoch': 5,
#   'node': 29,
#   'point': 1.1616127000689529e-07,
#   'ranking': 0.035763611827895656,
#   'speed': 5,
#   'validator': 0,
#   'vote': 6},
#  {'deposit': 395530,
#   'epoch': 6,
#   'node': 30,
#   'point': 1.2143109485586492e-08,
#   'ranking': 0.0415865110411069,
#   'speed': 6,
#   'validator': 0,
#   'vote': 2},
#  {'deposit': 393973,
#   'epoch': 6,
#   'node': 31,
#   'point': 4.250648801685333e-08,
#   'ranking': 0.0415635181809536,
#   'speed': 6,
#   'validator': 0,
#   'vote': 2},
#  {'deposit': 384180,
#   'epoch': 5,
#   'node': 32,
#   'point': 6.4045969774777635e-09,
#   'ranking': 0.03546130814119162,
#   'speed': 5,
#   'validator': 0,
#   'vote': 1},
#  {'deposit': 382955,
#   'epoch': 5,
#   'node': 33,
#   'point': 1.1376482723671762e-08,
#   'ranking': 0.0354432180617518,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 382843,
#   'epoch': 7,
#   'node': 34,
#   'point': 4.3038853507338446e-08,
#   'ranking': 0.04735674966388355,
#   'speed': 7,
#   'validator': 0,
#   'vote': 2},
#  {'deposit': 378089,
#   'epoch': 6,
#   'node': 35,
#   'point': 1.2441309434630853e-07,
#   'ranking': 0.0413289526121193,
#   'speed': 6,
#   'validator': 0,
#   'vote': 1},
#  {'deposit': 373902,
#   'epoch': 6,
#   'node': 36,
#   'point': 2.2474601070851285e-08,
#   'ranking': 0.0412671214589646,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 372937,
#   'epoch': 5,
#   'node': 37,
#   'point': 5.380983739272285e-08,
#   'ranking': 0.035295278130463584,
#   'speed': 5,
#   'validator': 0,
#   'vote': 1},
#  {'deposit': 372607,
#   'epoch': 8,
#   'node': 38,
#   'point': 1.418474272371942e-07,
#   'ranking': 0.05316318321295161,
#   'speed': 8,
#   'validator': 8,
#   'vote': 0},
#  {'deposit': 371418,
#   'epoch': 6,
#   'node': 39,
#   'point': 9.535457900132026e-08,
#   'ranking': 0.041230439208084196,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 369986,
#   'epoch': 7,
#   'node': 40,
#   'point': 1.3342457316668968e-07,
#   'ranking': 0.04716688505053032,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 367731,
#   'epoch': 9,
#   'node': 41,
#   'point': 1.4504655077419497e-07,
#   'ranking': 0.05904877008920122,
#   'speed': 9,
#   'validator': 109,
#   'vote': 0},
#  {'deposit': 365928,
#   'epoch': 9,
#   'node': 42,
#   'point': 5.619794938652918e-08,
#   'ranking': 0.05902214444574817,
#   'speed': 9,
#   'validator': 92,
#   'vote': 0},
#  {'deposit': 355582,
#   'epoch': 7,
#   'node': 43,
#   'point': 8.79797650133814e-08,
#   'ranking': 0.04695417525114168,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 352792,
#   'epoch': 7,
#   'node': 44,
#   'point': 1.4309522940457016e-07,
#   'ranking': 0.04691297417225426,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 352261,
#   'epoch': 6,
#   'node': 45,
#   'point': 4.4531703275919414e-08,
#   'ranking': 0.040947539900469065,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 350597,
#   'epoch': 6,
#   'node': 46,
#   'point': 5.942468688684126e-08,
#   'ranking': 0.04092296692725449,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 341912,
#   'epoch': 9,
#   'node': 47,
#   'point': 1.136214700904628e-07,
#   'ranking': 0.05866749028425708,
#   'speed': 9,
#   'validator': 106,
#   'vote': 0},
#  {'deposit': 335257,
#   'epoch': 7,
#   'node': 48,
#   'point': 2.282934217540018e-08,
#   'ranking': 0.04665402760655862,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 333040,
#   'epoch': 7,
#   'node': 49,
#   'point': 1.0089158751543434e-07,
#   'ranking': 0.046621288254625505,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 330479,
#   'epoch': 8,
#   'node': 50,
#   'point': 1.5160840125485664e-07,
#   'ranking': 0.05254106168916343,
#   'speed': 8,
#   'validator': 2,
#   'vote': 0},
#  {'deposit': 328167,
#   'epoch': 5,
#   'node': 51,
#   'point': 4.5899030132353625e-08,
#   'ranking': 0.03463414110473255,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 323741,
#   'epoch': 5,
#   'node': 52,
#   'point': 1.2322712084162436e-07,
#   'ranking': 0.03456878054016062,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 323400,
#   'epoch': 6,
#   'node': 53,
#   'point': 1.1575232914866388e-07,
#   'ranking': 0.04052133762886702,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 318738,
#   'epoch': 7,
#   'node': 54,
#   'point': 7.770614348320139e-08,
#   'ranking': 0.04641008473123919,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 315552,
#   'epoch': 5,
#   'node': 55,
#   'point': 1.2710066801288648e-07,
#   'ranking': 0.034447850205031924,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 312765,
#   'epoch': 6,
#   'node': 56,
#   'point': 1.3949461538761067e-07,
#   'ranking': 0.040364286204505856,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 312550,
#   'epoch': 6,
#   'node': 57,
#   'point': 1.0121476987972547e-07,
#   'ranking': 0.040361111210971516,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 310550,
#   'epoch': 5,
#   'node': 58,
#   'point': 1.6490951267379866e-08,
#   'ranking': 0.03437398361127033,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 310014,
#   'epoch': 9,
#   'node': 59,
#   'point': 1.5837527871598402e-08,
#   'ranking': 0.05819643938305608,
#   'speed': 9,
#   'validator': 75,
#   'vote': 0},
#  {'deposit': 308664,
#   'epoch': 5,
#   'node': 60,
#   'point': 8.929567361348663e-08,
#   'ranking': 0.034346132272638906,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 307236,
#   'epoch': 7,
#   'node': 61,
#   'point': 8.51115229063985e-08,
#   'ranking': 0.04624022996085817,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 303849,
#   'epoch': 9,
#   'node': 62,
#   'point': 1.6449060388684967e-07,
#   'ranking': 0.058105398289385504,
#   'speed': 9,
#   'validator': 69,
#   'vote': 0},
#  {'deposit': 303206,
#   'epoch': 7,
#   'node': 63,
#   'point': 5.7905130490889285e-08,
#   'ranking': 0.046180717291354124,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 302607,
#   'epoch': 6,
#   'node': 64,
#   'point': 9.155781447462769e-08,
#   'ranking': 0.04021427883556737,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 302314,
#   'epoch': 7,
#   'node': 65,
#   'point': 7.352797780854213e-08,
#   'ranking': 0.046167544760039585,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 300258,
#   'epoch': 6,
#   'node': 66,
#   'point': 5.3265930964236876e-08,
#   'ranking': 0.04017959018527829,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 293496,
#   'epoch': 7,
#   'node': 67,
#   'point': 9.942533465321769e-08,
#   'ranking': 0.04603732572289649,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 290516,
#   'epoch': 7,
#   'node': 68,
#   'point': 1.2523033414412727e-07,
#   'ranking': 0.04599331883576943,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 284583,
#   'epoch': 5,
#   'node': 69,
#   'point': 1.0311487349220667e-07,
#   'ranking': 0.033990518229381615,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 283747,
#   'epoch': 7,
#   'node': 70,
#   'point': 1.5801828624228156e-07,
#   'ranking': 0.04589335822537914,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 282984,
#   'epoch': 9,
#   'node': 71,
#   'point': 1.1299174717689716e-07,
#   'ranking': 0.05779727624243714,
#   'speed': 9,
#   'validator': 69,
#   'vote': 0},
#  {'deposit': 280808,
#   'epoch': 6,
#   'node': 72,
#   'point': 1.474026471318146e-07,
#   'ranking': 0.03989236402600939,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 279053,
#   'epoch': 6,
#   'node': 73,
#   'point': 2.8128013379587647e-08,
#   'ranking': 0.039866447218322144,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 278691,
#   'epoch': 7,
#   'node': 74,
#   'point': 6.283303658382966e-08,
#   'ranking': 0.045818694191381015,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 275259,
#   'epoch': 9,
#   'node': 75,
#   'point': 1.6945995880999643e-08,
#   'ranking': 0.0576831979863779,
#   'speed': 9,
#   'validator': 75,
#   'vote': 0},
#  {'deposit': 271004,
#   'epoch': 9,
#   'node': 76,
#   'point': 2.138398144163072e-07,
#   'ranking': 0.05762036264922165,
#   'speed': 9,
#   'validator': 82,
#   'vote': 0},
#  {'deposit': 267550,
#   'epoch': 9,
#   'node': 77,
#   'point': 1.5520132654085153e-07,
#   'ranking': 0.057569356008907266,
#   'speed': 9,
#   'validator': 62,
#   'vote': 0},
#  {'deposit': 266319,
#   'epoch': 7,
#   'node': 78,
#   'point': 3.563950689254679e-08,
#   'ranking': 0.04563599177274477,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 265984,
#   'epoch': 6,
#   'node': 79,
#   'point': 1.125432208259856e-07,
#   'ranking': 0.039673451913669944,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 264828,
#   'epoch': 7,
#   'node': 80,
#   'point': 1.741934554710873e-08,
#   'ranking': 0.04561397356176946,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 257409,
#   'epoch': 6,
#   'node': 81,
#   'point': 9.961199333306919e-08,
#   'ranking': 0.039546821357591244,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 256759,
#   'epoch': 5,
#   'node': 82,
#   'point': 4.887278960435134e-08,
#   'ranking': 0.03357962976380332,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 253702,
#   'epoch': 6,
#   'node': 83,
#   'point': 1.449544205053222e-07,
#   'ranking': 0.03949207856209459,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 253342,
#   'epoch': 8,
#   'node': 84,
#   'point': 1.382690460842716e-07,
#   'ranking': 0.05140194784610301,
#   'speed': 8,
#   'validator': 3,
#   'vote': 0},
#  {'deposit': 253018,
#   'epoch': 5,
#   'node': 85,
#   'point': 3.7716553238727765e-08,
#   'ranking': 0.03352438487630589,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 245707,
#   'epoch': 7,
#   'node': 86,
#   'point': 1.8534478463176693e-08,
#   'ranking': 0.04533160588097868,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 244063,
#   'epoch': 9,
#   'node': 87,
#   'point': 1.5203984254520272e-07,
#   'ranking': 0.05722251380825181,
#   'speed': 9,
#   'validator': 63,
#   'vote': 0},
#  {'deposit': 244033,
#   'epoch': 7,
#   'node': 88,
#   'point': 3.1930269914238484e-09,
#   'ranking': 0.04530688523364623,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 241765,
#   'epoch': 8,
#   'node': 89,
#   'point': 1.6053350572904372e-07,
#   'ranking': 0.051230985519837915,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 241153,
#   'epoch': 5,
#   'node': 90,
#   'point': 1.1729860363097078e-07,
#   'ranking': 0.03334916953544597,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 239828,
#   'epoch': 9,
#   'node': 91,
#   'point': 6.694120557869523e-09,
#   'ranking': 0.0571599738193313,
#   'speed': 9,
#   'validator': 50,
#   'vote': 0},
#  {'deposit': 238587,
#   'epoch': 7,
#   'node': 92,
#   'point': 1.4146890672719842e-07,
#   'ranking': 0.04522646190905094,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 230845,
#   'epoch': 8,
#   'node': 93,
#   'point': 1.3563230403702992e-07,
#   'ranking': 0.051069725383117284,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 227256,
#   'epoch': 5,
#   'node': 94,
#   'point': 7.896706750152233e-08,
#   'ranking': 0.03314394681383363,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 227169,
#   'epoch': 6,
#   'node': 95,
#   'point': 9.062045334687265e-08,
#   'ranking': 0.039100254825134094,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 222817,
#   'epoch': 6,
#   'node': 96,
#   'point': 8.8404411579272e-08,
#   'ranking': 0.039035987049034444,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 222015,
#   'epoch': 6,
#   'node': 97,
#   'point': 1.3155263729349402e-07,
#   'ranking': 0.039024143584780784,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 218923,
#   'epoch': 6,
#   'node': 98,
#   'point': 7.774552891870703e-08,
#   'ranking': 0.038978482747533516,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 215669,
#   'epoch': 6,
#   'node': 99,
#   'point': 4.6878673451673494e-08,
#   'ranking': 0.03893042958957665,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 213868,
#   'epoch': 9,
#   'node': 100,
#   'point': 1.598890753146133e-07,
#   'ranking': 0.056776611809325105,
#   'speed': 9,
#   'validator': 41,
#   'vote': 0},
#  {'deposit': 212922,
#   'epoch': 6,
#   'node': 101,
#   'point': 6.410579598441604e-09,
#   'ranking': 0.0388898635093961,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 211085,
#   'epoch': 6,
#   'node': 102,
#   'point': 7.545608813375838e-09,
#   'ranking': 0.038862735773942274,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 206457,
#   'epoch': 6,
#   'node': 103,
#   'point': 4.719983345855018e-08,
#   'ranking': 0.03879439219218924,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 201319,
#   'epoch': 6,
#   'node': 104,
#   'point': 5.119464306118661e-08,
#   'ranking': 0.038718517230424535,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 200139,
#   'epoch': 5,
#   'node': 105,
#   'point': 9.897270190187559e-08,
#   'ranking': 0.03274349890838918,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 194776,
#   'epoch': 9,
#   'node': 106,
#   'point': 2.2884238189000028e-08,
#   'ranking': 0.05649467238347616,
#   'speed': 9,
#   'validator': 60,
#   'vote': 0},
#  {'deposit': 194525,
#   'epoch': 5,
#   'node': 107,
#   'point': 2.567750183547601e-08,
#   'ranking': 0.03266059465861357,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 190632,
#   'epoch': 6,
#   'node': 108,
#   'point': 5.9331367877071076e-08,
#   'ranking': 0.038560697900650406,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 188082,
#   'epoch': 6,
#   'node': 109,
#   'point': 4.504660495989627e-08,
#   'ranking': 0.038523041000592013,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 186507,
#   'epoch': 9,
#   'node': 110,
#   'point': 1.2502485813616172e-07,
#   'ranking': 0.05637256065540447,
#   'speed': 9,
#   'validator': 28,
#   'vote': 0},
#  {'deposit': 182919,
#   'epoch': 5,
#   'node': 111,
#   'point': 9.209999657452223e-08,
#   'ranking': 0.03248920407740664,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 179051,
#   'epoch': 6,
#   'node': 112,
#   'point': 5.97988952272949e-08,
#   'ranking': 0.038389676504738166,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 173540,
#   'epoch': 6,
#   'node': 113,
#   'point': 3.974943313194927e-08,
#   'ranking': 0.03830829329837668,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 171960,
#   'epoch': 5,
#   'node': 114,
#   'point': 5.5073344777282825e-08,
#   'ranking': 0.032327368011626285,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 171009,
#   'epoch': 5,
#   'node': 115,
#   'point': 3.535408114463967e-08,
#   'ranking': 0.032313324203016275,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 167420,
#   'epoch': 8,
#   'node': 116,
#   'point': 9.12524520239196e-08,
#   'ranking': 0.05013310229048849,
#   'speed': 8,
#   'validator': 1,
#   'vote': 0},
#  {'deposit': 159748,
#   'epoch': 7,
#   'node': 117,
#   'point': 7.309065797635615e-08,
#   'ranking': 0.044062213931128025,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 154862,
#   'epoch': 7,
#   'node': 118,
#   'point': 9.150219059455026e-08,
#   'ranking': 0.04399006035713379,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 144450,
#   'epoch': 6,
#   'node': 119,
#   'point': 6.620694206540748e-08,
#   'ranking': 0.037878709289475274,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 137327,
#   'epoch': 9,
#   'node': 120,
#   'point': 2.0134765370124354e-07,
#   'ranking': 0.0556462993436901,
#   'speed': 9,
#   'validator': 32,
#   'vote': 0},
#  {'deposit': 135116,
#   'epoch': 7,
#   'node': 121,
#   'point': 5.0142258177109576e-08,
#   'ranking': 0.04369846304397576,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 127582,
#   'epoch': 7,
#   'node': 122,
#   'point': 7.044293736299569e-08,
#   'ranking': 0.04358720536356795,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 125565,
#   'epoch': 5,
#   'node': 123,
#   'point': 2.8926755698903064e-08,
#   'ranking': 0.03164223394174039,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 125383,
#   'epoch': 5,
#   'node': 124,
#   'point': 3.195663796790022e-08,
#   'ranking': 0.03163954627279505,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 121150,
#   'epoch': 7,
#   'node': 125,
#   'point': 1.5302010678138357e-07,
#   'ranking': 0.04349222137095008,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 120555,
#   'epoch': 8,
#   'node': 126,
#   'point': 1.6672786018423126e-07,
#   'ranking': 0.04944102753706243,
#   'speed': 8,
#   'validator': 1,
#   'vote': 0},
#  {'deposit': 120131,
#   'epoch': 7,
#   'node': 127,
#   'point': 1.3648067560622506e-07,
#   'ranking': 0.043477173378338514,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 116314,
#   'epoch': 5,
#   'node': 128,
#   'point': 3.257561050709234e-08,
#   'ranking': 0.031505620615293266,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 115999,
#   'epoch': 7,
#   'node': 129,
#   'point': 7.42508768551103e-08,
#   'ranking': 0.04341615443283214,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 110313,
#   'epoch': 9,
#   'node': 130,
#   'point': 6.602391298696839e-09,
#   'ranking': 0.055247372481659764,
#   'speed': 9,
#   'validator': 29,
#   'vote': 0},
#  {'deposit': 107523,
#   'epoch': 9,
#   'node': 131,
#   'point': 1.9844834119492226e-07,
#   'ranking': 0.05520617140277235,
#   'speed': 9,
#   'validator': 22,
#   'vote': 0},
#  {'deposit': 104490,
#   'epoch': 9,
#   'node': 132,
#   'point': 1.362832427816264e-07,
#   'ranking': 0.055161381842820545,
#   'speed': 9,
#   'validator': 29,
#   'vote': 0},
#  {'deposit': 100735,
#   'epoch': 9,
#   'node': 133,
#   'point': 9.271998934695504e-08,
#   'ranking': 0.055105930211558095,
#   'speed': 9,
#   'validator': 16,
#   'vote': 0},
#  {'deposit': 91486,
#   'epoch': 8,
#   'node': 134,
#   'point': 4.738877608333415e-08,
#   'ranking': 0.04901175364380857,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 86917,
#   'epoch': 8,
#   'node': 135,
#   'point': 1.5297081364412963e-07,
#   'ranking': 0.048944281339351005,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 86325,
#   'epoch': 5,
#   'node': 136,
#   'point': 5.951196321734957e-08,
#   'ranking': 0.03106276070319481,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 83536,
#   'epoch': 7,
#   'node': 137,
#   'point': 1.2137073647117717e-07,
#   'ranking': 0.04293675994397114,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 83526,
#   'epoch': 6,
#   'node': 138,
#   'point': 8.179992960938323e-08,
#   'ranking': 0.03697901949372728,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 79355,
#   'epoch': 7,
#   'node': 139,
#   'point': 1.1956675397805132e-07,
#   'ranking': 0.04287501739528717,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 79313,
#   'epoch': 6,
#   'node': 140,
#   'point': 1.0395556819108935e-07,
#   'ranking': 0.03691680438786611,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 74785,
#   'epoch': 5,
#   'node': 141,
#   'point': 5.301295300487374e-08,
#   'ranking': 0.03089234477116586,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 70668,
#   'epoch': 6,
#   'node': 142,
#   'point': 9.139583143015436e-08,
#   'ranking': 0.036789140112962276,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 65608,
#   'epoch': 8,
#   'node': 143,
#   'point': 1.1604491569094497e-07,
#   'ranking': 0.04862960256156895,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 63642,
#   'epoch': 8,
#   'node': 144,
#   'point': 1.784342075678748e-07,
#   'ranking': 0.04860056982999452,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 62878,
#   'epoch': 8,
#   'node': 145,
#   'point': 5.1985308369598026e-08,
#   'ranking': 0.048589287527388794,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 59577,
#   'epoch': 6,
#   'node': 146,
#   'point': 1.1167041447997913e-07,
#   'ranking': 0.03662535474882596,
#   'speed': 6,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 58229,
#   'epoch': 5,
#   'node': 147,
#   'point': 1.0839341581352853e-07,
#   'ranking': 0.030647855501610286,
#   'speed': 5,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 57242,
#   'epoch': 8,
#   'node': 148,
#   'point': 4.100671889614125e-08,
#   'ranking': 0.04850605839455385,
#   'speed': 8,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 53583,
#   'epoch': 7,
#   'node': 149,
#   'point': 1.0443400305357399e-07,
#   'ranking': 0.04249443165869704,
#   'speed': 7,
#   'validator': 0,
#   'vote': 0},
#  {'deposit': 52738,
#   'epoch': 5,
#   'node': 150,
#   'point': 0,
#   'ranking': 0.030566767643484552,
#   'speed': 5,
#   'validator': 1,
#   'vote': 0}]
