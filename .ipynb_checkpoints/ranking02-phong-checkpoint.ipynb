# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from math import *

# %%
arr = np.random.rand(2)
print(arr)
arr[::-1].sort()
print(arr)
# Out:
# [0.6622095  0.92095443]
# [0.92095443 0.6622095 ]

# %%
NUMBER_OF_NODE = 10;
NUMBER_OF_VOTE = "number_of_vote"
POINT = "point"
NUMBER_OF_VALIDATOR = "number_of_validator"

#init nodes
def init_nodes(number_of_node):
    nodes = []
    for i in range(number_of_node):
        nodes.append({})
        nodes[i][NUMBER_OF_VOTE] = 0
        nodes[i][NUMBER_OF_VALIDATOR] = 0
        nodes[i][POINT] = 0
    
    return nodes

# %%
def simulator(nodes):
    if len(nodes) == 0:
        print("number of node is 0, return")
        return
    #select leader
    
    #random array with length is number of canidate of leader
    rand_arr = np.random.rand(len(nodes)).tolist()
    for i in range(len(rand_arr)):
        nodes[i][POINT] += rand_arr[i]
    
    #select lead node
    index_of_leader = -1
    maximum = -1
    for i in range(len(rand_arr)):
        if rand_arr[i] > maximum:
            index_of_leader = i
            maximum = rand_arr[i]
    if index_of_leader == -1:
        print("index of leader is -1, return")
        return
    nodes[index_of_leader][NUMBER_OF_VOTE] += 1
    
    #select validator
    
    point_arr = []
    total = 0
    for i in range(len(nodes)):
        if i != index_of_leader:
            total += nodes[i][POINT]
            point_arr.append(nodes[i][POINT])
    mean = total/(len(nodes) - 1)
    
    rand_ranking = np.random.rand(len(nodes) -1).tolist()
    
    
    index_of_validator = -1
    maximum = -1
    for i in range(len(rand_ranking)):
        if mean != 0:
            rank_point = rand_ranking[i] * point_arr[i] * 1/mean
        else:
            rank_point = rand_ranking[i] * point_arr[i]
        if rank_point > maximum:
            index_of_validator = i
            maximum = rank_point
     
    if index_of_validator == -1:
        print("index of validator is -1, return")
    if index_of_validator >= index_of_leader:
        nodes[index_of_validator + 1][NUMBER_OF_VALIDATOR] += 1
    else:
        nodes[index_of_validator][NUMBER_OF_VALIDATOR] += 1

# %%
nodes = init_nodes(100)
for k in range(200):
    simulator(nodes)
print(nodes)
# Out:
# [{'number_of_vote': 0, 'number_of_validator': 0, 'point': 93.06815468467947}, {'number_of_vote': 2, 'number_of_validator': 0, 'point': 98.58623059513415}, {'number_of_vote': 2, 'number_of_validator': 6, 'point': 103.07097093276563}, {'number_of_vote': 1, 'number_of_validator': 0, 'point': 100.0624699628977}, {'number_of_vote': 4, 'number_of_validator': 16, 'point': 108.50544072973807}, {'number_of_vote': 0, 'number_of_validator': 0, 'point': 92.29915393598623}, {'number_of_vote': 4, 'number_of_validator': 6, 'point': 100.91844269674985}, {'number_of_vote': 2, 'number_of_validator': 0, 'point': 96.64770829365906}, {'number_of_vote': 2, 'number_of_validator': 0, 'point': 95.1554030467313}, {'number_of_vote': 2, 'number_of_validator': 1, 'point': 103.95242729059319}, {'number_of_vote': 3, 'number_of_validator': 4, 'point': 99.43248532394908}, {'number_of_vote': 0, 'number_of_validator': 0, 'point': 103.21084528828834}, {'number_of_vote': 1, 'number_of_validator': 0, 'point': 92.7032012971982}, {'number_of_vote': 1, 'number_of_validator': 0, 'point': 99.0662376879568}, {'number_of_vote': 6, 'number_of_validator': 6, 'point': 104.8018664066268}, {'number_of_vote': 6, 'number_of_validator': 0, 'point': 98.7615800485249}, {'number_of_vote': 1, 'number_of_validator': 5, 'point': 106.66603410771891}, {'number_of_vote': 1, 'number_of_validator': 3, 'point': 99.59442532429013}, {'number_of_vote': 2, 'number_of_validator': 1, 'point': 97.21243388398213}, {'number_of_vote': 2, 'number_of_validator': 0, 'point': 99.0675894648675}, {'number_of_vote': 0, 'number_of_validator': 5, 'point': 103.63709249405296}, {'number_of_vote': 1, 'number_of_validator': 3, 'point': 100.67865362786472}, {'number_of_vote': 1, 'number_of_validator': 0, 'point': 92.36540100624447}, {'number_of_vote': 3, 'number_of_validator': 0, 'point': 99.27939348315232}, {'number_of_vote': 0, 'number_of_validator': 0, 'point': 90.63286581003287}, {'number_of_vote': 2, 'number_of_validator': 1, 'point': 100.34428295961973}, {'number_of_vote': 1, 'number_of_validator': 0, 'point': 97.10238886145022}, {'number_of_vote': 4, 'number_of_validator': 0, 'point': 93.97318638238036}, {'number_of_vote': 1, 'number_of_validator': 3, 'point': 100.00297878247471}, {'number_of_vote': 1, 'number_of_validator': 4, 'point': 104.64019895432672}, {'number_of_vote': 2, 'number_of_validator': 7, 'point': 107.72087832500206}, {'number_of_vote': 3, 'number_of_validator': 4, 'point': 99.32154655212436}, {'number_of_vote': 4, 'number_of_validator': 1, 'point': 102.45647778329669}, {'number_of_vote': 4, 'number_of_validator': 2, 'point': 101.33006267926869}, {'number_of_vote': 2, 'number_of_validator': 0, 'point': 100.12611187374499}, {'number_of_vote': 2, 'number_of_validator': 10, 'point': 105.1966355705907}, {'number_of_vote': 3, 'number_of_validator': 1, 'point': 99.03801749092484}, {'number_of_vote': 4, 'number_of_validator': 0, 'point': 95.56239509951922}, {'number_of_vote': 3, 'number_of_validator': 0, 'point': 91.93330766528274}, {'number_of_vote': 2, 'number_of_validator': 0, 'point': 99.72352845847155}, {'number_of_vote': 1, 'number_of_validator': 0, 'point': 94.50889969606173}, {'number_of_vote': 0, 'number_of_validator': 0, 'point': 102.77569340973031}, {'number_of_vote': 2, 'number_of_validator': 1, 'point': 101.51094457968907}, {'number_of_vote': 1, 'number_of_validator': 4, 'point': 100.81780497989352}, {'number_of_vote': 0, 'number_of_validator': 0, 'point': 95.75768347370752}, {'number_of_vote': 1, 'number_of_validator': 0, 'point': 97.25501474886696}, {'number_of_vote': 2, 'number_of_validator': 2, 'point': 98.93793075510554}, {'number_of_vote': 1, 'number_of_validator': 0, 'point': 97.26449828323865}, {'number_of_vote': 2, 'number_of_validator': 3, 'point': 102.31990205247304}, {'number_of_vote': 2, 'number_of_validator': 0, 'point': 98.44221125276837}, {'number_of_vote': 0, 'number_of_validator': 1, 'point': 98.57678185939237}, {'number_of_vote': 2, 'number_of_validator': 3, 'point': ...

# %%
x_array = []
leader_y_array = []
validator_y_array = []
points_y_array = []
for i in range(len(nodes)):
    x_array.append(i)
    leader_y_array.append(nodes[i][NUMBER_OF_VOTE])
    validator_y_array.append(nodes[i][NUMBER_OF_VALIDATOR])
    points_y_array.append(nodes[i][POINT])
plt.xlabel("node index")
plt.ylabel("number of times selected")

plt.plot(x_array, leader_y_array, label='leader')
plt.plot(x_array, validator_y_array, label='validator')
plt.legend()
plt.show()

# %%
plt.xlabel("node index")
plt.ylabel("point of node")

plt.plot(x_array, points_y_array, label='points')
plt.legend()
plt.show()
